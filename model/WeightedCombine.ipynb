# %%
import joblib
import numpy as np
from sklearn.model_selection import train_test_split, KFold
import xgboost as xgb
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2

# %%
prev_notebook_folder = "./"
loans = joblib.load(prev_notebook_folder + "data_for_eval.joblib")
loans["date"] = loans["issue_d"].astype("datetime64[ns]")
loans.sort_values("date", axis="index", inplace=True, kind="mergesort")

loans.head()
# Out:
# /var/folders/d5/hpc31dsx59l4rfyrs6m6yvp00000gn/T/ipykernel_16777/655926190.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   loans["date"] = loans["issue_d"].astype("datetime64[ns]")
#          loan_amnt       term emp_length home_ownership  annual_inc
# 1909203     2125.0  36 months    3 years       MORTGAGE     45000.0  \
# 1909437    28000.0  60 months  10+ years       MORTGAGE    150000.0
# 1909457    14125.0  36 months    3 years           RENT     36000.0
# 1909558    16000.0  60 months  10+ years           RENT     58900.0
# 1909566     2800.0  36 months    4 years           RENT     89000.0
#
#                     purpose    dti  delinq_2yrs  cr_hist_age_mths
# 1909203    home_improvement  15.88          1.0             137.0  \
# 1909437  debt_consolidation   5.96          1.0             198.0
# 1909457  debt_consolidation  18.93          0.0             107.0
# 1909558  debt_consolidation  33.53          0.0             141.0
# 1909566  debt_consolidation  15.18          0.0             295.0
#
#          fico_range_low  ...  tot_hi_cred_lim  total_bal_ex_mort
# 1909203           660.0  ...         146436.0            23662.0  \
# 1909437           685.0  ...         417242.0            27924.0
# 1909457           665.0  ...          58087.0            57612.0
# 1909558           700.0  ...          83557.0            69752.0
# 1909566           670.0  ...          51892.0            50262.0
#
#          total_bc_limit  total_il_high_credit_limit  recovered_percentage
# 1909203          3200.0                     22483.0              1.000000  \
# 1909437         31432.0                     25523.0              0.446871
# 1909457          7900.0                     47687.0              1.000000
# 1909558          1800.0                     69657.0              0.327324
# 1909566          2500.0                     44992.0              1.000000
#
#           issue_d  grade  sub_grade  expected_return       date
# 1909203  Aug-2012      C         C5          2737.80 2012-08-01
# 1909437  Aug-2012      E         E4         46381.20 2012-08-01
# 1909457  Aug-2012      D         D3         18575.64 2012-08-01
# 1909558  Aug-2012      E         E1         25696.80 2012-08-01
# 1909566  Aug-2012      C         C2          3509.64 2012-08-01
#
# [5 rows x 71 columns]

# %%
train, test = train_test_split(loans, test_size=0.2, shuffle=False)
train_nn, train_xgb, test_nn, test_xgb = train.copy(), train.copy(), test.copy(), test.copy()
print(f"The test set contains {len(test):,} loans.")

onehot_cols = ["term", "application_type", "home_ownership", "purpose"]
ordinal_cols = {
    "emp_length": [
        "< 1 year",
        "1 year",
        "2 years",
        "3 years",
        "4 years",
        "5 years",
        "6 years",
        "7 years",
        "8 years",
        "9 years",
        "10+ years",
    ]
}
# Out:
# The test set contains 222,035 loans.

# %%
def run_pipeline_cv(data, onehot_cols, ordinal_cols, model_type="nn", batch_size=None):
    X = data.drop(columns=["recovered_percentage"])
    y = data["recovered_percentage"]

    transformer = DataFrameMapper(
        [
            (onehot_cols, OneHotEncoder(drop="if_binary", handle_unknown="ignore")),
            (
                list(ordinal_cols.keys()),
                OrdinalEncoder(categories=list(ordinal_cols.values())),
            ),
        ],
        default=StandardScaler(),
    )

    cv = KFold(n_splits=5, shuffle=True, random_state=0)

    history_list = []
    model_list = []
    transformer_list = []

    for train_idx, valid_idx in cv.split(X):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        X_train = transformer.fit_transform(X_train)
        X_valid = transformer.transform(X_valid)

        if model_type == "nn":
            input_nodes = X_train.shape[1]
            output_nodes = 1

            learning_rate = 0.002
            momentum = 0.9
            optimizer = SGD(learning_rate=learning_rate, momentum=momentum)

            reg_strength = 0.001  # Set regularization strength
            regularizer = l2(reg_strength)  # Create an L2 regularizer

            model = Sequential()
            model.add(Input((input_nodes,)))
            model.add(Dense(64, activation="relu", kernel_regularizer=regularizer))
            model.add(Dropout(0.3, seed=0))
            model.add(Dense(32, activation="relu", kernel_regularizer=regularizer))
            model.add(Dropout(0.3, seed=1))
            model.add(Dense(16, activation="relu", kernel_regularizer=regularizer))
            model.add(Dropout(0.3, seed=2))
            model.add(Dense(output_nodes, kernel_regularizer=regularizer))
            model.compile(optimizer=optimizer, loss="mean_squared_logarithmic_error")

            history = model.fit(
                X_train,
                y_train,
                batch_size=batch_size,
                epochs=25,
                validation_data=(X_valid, y_valid),
                verbose=2,
            )
            history_list.append(history.history)
        elif model_type == "xgb":
            model = xgb.XGBRegressor(objective="reg:squarederror")
            model.fit(X_train, y_train)
            history_list.append(None)

        model_list.append(model)
        transformer_list.append(transformer)

    return history_list, model_list, transformer_list

# %%
def make_predictions(data, model_list, transformer_list):
    predictions_list = []

    for i in range(len(model_list)):
        model = model_list[i]
        transformer = transformer_list[i]

        X_test = transformer.transform(
            data.drop(
                columns=[
                    "recovered_percentage",
                    "issue_d",
                    "date",
                    "grade",
                    "sub_grade",
                    "expected_return",
                ]
            )
        )

        predictions = model.predict(X_test)
        predictions_list.append(predictions)

    data["model_predictions"] = np.mean(predictions_list, axis=0)

# %%
# Run the pipeline with cross-validation for neural network
nn_history_list, nn_model_list, nn_transformer_list = run_pipeline_cv(
    train_nn.drop(columns=["issue_d", "date", "grade", "sub_grade", "expected_return"]),
    onehot_cols,
    ordinal_cols,
    model_type="nn",
    batch_size=128,
)

# Make predictions for neural network
make_predictions(test_nn, nn_model_list, nn_transformer_list)

# Run the pipeline with cross-validation for XGBoost
xgb_history_list, xgb_model_list, xgb_transformer_list = run_pipeline_cv(
    train_xgb.drop(columns=["issue_d", "date", "grade", "sub_grade", "expected_return"]),
    onehot_cols,
    ordinal_cols,
    model_type="xgb",
)

# Make predictions for XGBoost
make_predictions(test_xgb, xgb_model_list, xgb_transformer_list)

# Define the weights for each model
xgb_weight = 0.6
nn_weight = 0.4

# Calculate the weighted average of the predictions
test["model_predictions"] = (xgb_weight * test_xgb["model_predictions"]) + (nn_weight * test_nn["model_predictions"])
# Out:
# Epoch 1/25
# 5551/5551 - 9s - loss: 0.1355 - val_loss: 0.1075 - 9s/epoch - 2ms/step
# Epoch 2/25
# 5551/5551 - 7s - loss: 0.0911 - val_loss: 0.0770 - 7s/epoch - 1ms/step
# Epoch 3/25
# 5551/5551 - 8s - loss: 0.0665 - val_loss: 0.0573 - 8s/epoch - 1ms/step
# Epoch 4/25
# 5551/5551 - 8s - loss: 0.0506 - val_loss: 0.0446 - 8s/epoch - 1ms/step
# Epoch 5/25
# 5551/5551 - 7s - loss: 0.0404 - val_loss: 0.0364 - 7s/epoch - 1ms/step
# Epoch 6/25
# 5551/5551 - 7s - loss: 0.0338 - val_loss: 0.0312 - 7s/epoch - 1ms/step
# Epoch 7/25
# 5551/5551 - 7s - loss: 0.0296 - val_loss: 0.0278 - 7s/epoch - 1ms/step
# Epoch 8/25
# 5551/5551 - 7s - loss: 0.0269 - val_loss: 0.0256 - 7s/epoch - 1ms/step
# Epoch 9/25
# 5551/5551 - 7s - loss: 0.0251 - val_loss: 0.0242 - 7s/epoch - 1ms/step
# Epoch 10/25
# 5551/5551 - 7s - loss: 0.0240 - val_loss: 0.0234 - 7s/epoch - 1ms/step
# Epoch 11/25
# 5551/5551 - 7s - loss: 0.0233 - val_loss: 0.0228 - 7s/epoch - 1ms/step
# Epoch 12/25
# 5551/5551 - 8s - loss: 0.0228 - val_loss: 0.0224 - 8s/epoch - 1ms/step
# Epoch 13/25
# 5551/5551 - 10s - loss: 0.0225 - val_loss: 0.0222 - 10s/epoch - 2ms/step
# Epoch 14/25
# 5551/5551 - 8s - loss: 0.0223 - val_loss: 0.0220 - 8s/epoch - 1ms/step
# Epoch 15/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 16/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 17/25
# 5551/5551 - 8s - loss: 0.0221 - val_loss: 0.0218 - 8s/epoch - 1ms/step
# Epoch 18/25
# 5551/5551 - 9s - loss: 0.0221 - val_loss: 0.0218 - 9s/epoch - 2ms/step
# Epoch 19/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 20/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 21/25
# 5551/5551 - 8s - loss: 0.0220 - val_loss: 0.0217 - 8s/epoch - 1ms/step
# Epoch 22/25
# 5551/5551 - 8s - loss: 0.0220 - val_loss: 0.0217 - 8s/epoch - 1ms/step
# Epoch 23/25
# 5551/5551 - 8s - loss: 0.0220 - val_loss: 0.0217 - 8s/epoch - 1ms/step
# Epoch 24/25
# 5551/5551 - 8s - loss: 0.0220 - val_loss: 0.0217 - 8s/epoch - 1ms/step
# Epoch 25/25
# 5551/5551 - 10s - loss: 0.0220 - val_loss: 0.0217 - 10s/epoch - 2ms/step
# Epoch 1/25
# 5551/5551 - 10s - loss: 0.1385 - val_loss: 0.1092 - 10s/epoch - 2ms/step
# Epoch 2/25
# 5551/5551 - 9s - loss: 0.0924 - val_loss: 0.0781 - 9s/epoch - 2ms/step
# Epoch 3/25
# 5551/5551 - 8s - loss: 0.0673 - val_loss: 0.0581 - 8s/epoch - 1ms/step
# Epoch 4/25
# 5551/5551 - 9s - loss: 0.0512 - val_loss: 0.0452 - 9s/epoch - 2ms/step
# Epoch 5/25
# 5551/5551 - 7s - loss: 0.0407 - val_loss: 0.0368 - 7s/epoch - 1ms/step
# Epoch 6/25
# 5551/5551 - 8s - loss: 0.0340 - val_loss: 0.0315 - 8s/epoch - 1ms/step
# Epoch 7/25
# 5551/5551 - 9s - loss: 0.0297 - val_loss: 0.0280 - 9s/epoch - 2ms/step
# Epoch 8/25
# 5551/5551 - 8s - loss: 0.0270 - val_loss: 0.0258 - 8s/epoch - 1ms/step
# Epoch 9/25
# 5551/5551 - 7s - loss: 0.0252 - val_loss: 0.0244 - 7s/epoch - 1ms/step
# Epoch 10/25
# 5551/5551 - 7s - loss: 0.0240 - val_loss: 0.0235 - 7s/epoch - 1ms/step
# Epoch 11/25
# 5551/5551 - 8s - loss: 0.0233 - val_loss: 0.0229 - 8s/epoch - 1ms/step
# Epoch 12/25
# 5551/5551 - 8s - loss: 0.0228 - val_loss: 0.0225 - 8s/epoch - 1ms/step
# Epoch 13/25
# 5551/5551 - 9s - loss: 0.0225 - val_loss: 0.0222 - 9s/epoch - 2ms/step
# Epoch 14/25
# 5551/5551 - 8s - loss: 0.0223 - val_loss: 0.0221 - 8s/epoch - 1ms/step
# Epoch 15/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0220 - 7s/epoch - 1ms/step
# Epoch 16/25
# 5551/5551 - 7s - loss: 0.0221 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 17/25
# 5551/5551 - 7s - loss: 0.0221 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 18/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 19/25
# 5551/5551 - 9s - loss: 0.0220 - val_loss: 0.0218 - 9s/epoch - 2ms/step
# Epoch 20/25
# 5551/5551 - 8s - loss: 0.0220 - val_loss: 0.0218 - 8s/epoch - 1ms/step
# Epoch 21/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 22/25
# 5551/5551 - 7s - loss: 0.0219 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 23/25
# 5551/5551 - 7s - loss: 0.0219 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 24/25
# 5551/5551 - 8s - loss: 0.0219 - val_loss: 0.0218 - 8s/epoch - 1ms/step
# Epoch 25/25
# 5551/5551 - 7s - loss: 0.0219 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 1/25
# 5551/5551 - 9s - loss: 0.1363 - val_loss: 0.1095 - 9s/epoch - 2ms/step
# Epoch 2/25
# 5551/5551 - 8s - loss: 0.0929 - val_loss: 0.0782 - 8s/epoch - 1ms/step
# Epoch 3/25
# 5551/5551 - 7s - loss: 0.0676 - val_loss: 0.0581 - 7s/epoch - 1ms/step
# Epoch 4/25
# 5551/5551 - 7s - loss: 0.0514 - val_loss: 0.0452 - 7s/epoch - 1ms/step
# Epoch 5/25
# 5551/5551 - 8s - loss: 0.0410 - val_loss: 0.0370 - 8s/epoch - 1ms/step
# Epoch 6/25
# 5551/5551 - 9s - loss: 0.0344 - val_loss: 0.0317 - 9s/epoch - 2ms/step
# Epoch 7/25
# 5551/5551 - 7s - loss: 0.0301 - val_loss: 0.0283 - 7s/epoch - 1ms/step
# Epoch 8/25
# 5551/5551 - 7s - loss: 0.0274 - val_loss: 0.0261 - 7s/epoch - 1ms/step
# Epoch 9/25
# 5551/5551 - 8s - loss: 0.0256 - val_loss: 0.0247 - 8s/epoch - 1ms/step
# Epoch 10/25
# 5551/5551 - 7s - loss: 0.0245 - val_loss: 0.0237 - 7s/epoch - 1ms/step
# Epoch 11/25
# 5551/5551 - 9s - loss: 0.0237 - val_loss: 0.0231 - 9s/epoch - 2ms/step
# Epoch 12/25
# 5551/5551 - 9s - loss: 0.0232 - val_loss: 0.0227 - 9s/epoch - 2ms/step
# Epoch 13/25
# 5551/5551 - 8s - loss: 0.0229 - val_loss: 0.0224 - 8s/epoch - 1ms/step
# Epoch 14/25
# 5551/5551 - 7s - loss: 0.0227 - val_loss: 0.0222 - 7s/epoch - 1ms/step
# Epoch 15/25
# 5551/5551 - 7s - loss: 0.0225 - val_loss: 0.0221 - 7s/epoch - 1ms/step
# Epoch 16/25
# 5551/5551 - 7s - loss: 0.0224 - val_loss: 0.0220 - 7s/epoch - 1ms/step
# Epoch 17/25
# 5551/5551 - 7s - loss: 0.0224 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 18/25
# 5551/5551 - 7s - loss: 0.0223 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 19/25
# 5551/5551 - 7s - loss: 0.0223 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 20/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 21/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 22/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 23/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 24/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 25/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 1/25
# 5551/5551 - 8s - loss: 0.1351 - val_loss: 0.1087 - 8s/epoch - 1ms/step
# Epoch 2/25
# 5551/5551 - 7s - loss: 0.0921 - val_loss: 0.0778 - 7s/epoch - 1ms/step
# Epoch 3/25
# 5551/5551 - 7s - loss: 0.0671 - val_loss: 0.0579 - 7s/epoch - 1ms/step
# Epoch 4/25
# 5551/5551 - 7s - loss: 0.0511 - val_loss: 0.0452 - 7s/epoch - 1ms/step
# Epoch 5/25
# 5551/5551 - 8s - loss: 0.0408 - val_loss: 0.0370 - 8s/epoch - 1ms/step
# Epoch 6/25
# 5551/5551 - 9s - loss: 0.0342 - val_loss: 0.0317 - 9s/epoch - 2ms/step
# Epoch 7/25
# 5551/5551 - 8s - loss: 0.0299 - val_loss: 0.0283 - 8s/epoch - 1ms/step
# Epoch 8/25
# 5551/5551 - 7s - loss: 0.0272 - val_loss: 0.0260 - 7s/epoch - 1ms/step
# Epoch 9/25
# 5551/5551 - 7s - loss: 0.0254 - val_loss: 0.0246 - 7s/epoch - 1ms/step
# Epoch 10/25
# 5551/5551 - 7s - loss: 0.0242 - val_loss: 0.0236 - 7s/epoch - 1ms/step
# Epoch 11/25
# 5551/5551 - 7s - loss: 0.0235 - val_loss: 0.0229 - 7s/epoch - 1ms/step
# Epoch 12/25
# 5551/5551 - 7s - loss: 0.0230 - val_loss: 0.0225 - 7s/epoch - 1ms/step
# Epoch 13/25
# 5551/5551 - 7s - loss: 0.0226 - val_loss: 0.0222 - 7s/epoch - 1ms/step
# Epoch 14/25
# 5551/5551 - 7s - loss: 0.0224 - val_loss: 0.0221 - 7s/epoch - 1ms/step
# Epoch 15/25
# 5551/5551 - 7s - loss: 0.0223 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 16/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0219 - 7s/epoch - 1ms/step
# Epoch 17/25
# 5551/5551 - 7s - loss: 0.0221 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 18/25
# 5551/5551 - 7s - loss: 0.0221 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 19/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 20/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 21/25
# 5551/5551 - 8s - loss: 0.0220 - val_loss: 0.0217 - 8s/epoch - 1ms/step
# Epoch 22/25
# 5551/5551 - 8s - loss: 0.0220 - val_loss: 0.0217 - 8s/epoch - 1ms/step
# Epoch 23/25
# 5551/5551 - 8s - loss: 0.0220 - val_loss: 0.0217 - 8s/epoch - 1ms/step
# Epoch 24/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 25/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 1/25
# 5551/5551 - 8s - loss: 0.1361 - val_loss: 0.1070 - 8s/epoch - 1ms/step
# Epoch 2/25
# 5551/5551 - 7s - loss: 0.0908 - val_loss: 0.0766 - 7s/epoch - 1ms/step
# Epoch 3/25
# 5551/5551 - 7s - loss: 0.0662 - val_loss: 0.0570 - 7s/epoch - 1ms/step
# Epoch 4/25
# 5551/5551 - 7s - loss: 0.0505 - val_loss: 0.0445 - 7s/epoch - 1ms/step
# Epoch 5/25
# 5551/5551 - 9s - loss: 0.0404 - val_loss: 0.0364 - 9s/epoch - 2ms/step
# Epoch 6/25
# 5551/5551 - 8s - loss: 0.0339 - val_loss: 0.0312 - 8s/epoch - 1ms/step
# Epoch 7/25
# 5551/5551 - 8s - loss: 0.0297 - val_loss: 0.0279 - 8s/epoch - 1ms/step
# Epoch 8/25
# 5551/5551 - 8s - loss: 0.0270 - val_loss: 0.0257 - 8s/epoch - 1ms/step
# Epoch 9/25
# 5551/5551 - 7s - loss: 0.0253 - val_loss: 0.0243 - 7s/epoch - 1ms/step
# Epoch 10/25
# 5551/5551 - 7s - loss: 0.0242 - val_loss: 0.0234 - 7s/epoch - 1ms/step
# Epoch 11/25
# 5551/5551 - 7s - loss: 0.0234 - val_loss: 0.0228 - 7s/epoch - 1ms/step
# Epoch 12/25
# 5551/5551 - 7s - loss: 0.0229 - val_loss: 0.0224 - 7s/epoch - 1ms/step
# Epoch 13/25
# 5551/5551 - 7s - loss: 0.0226 - val_loss: 0.0222 - 7s/epoch - 1ms/step
# Epoch 14/25
# 5551/5551 - 7s - loss: 0.0224 - val_loss: 0.0220 - 7s/epoch - 1ms/step
# Epoch 15/25
# 5551/5551 - 8s - loss: 0.0223 - val_loss: 0.0219 - 8s/epoch - 1ms/step
# Epoch 16/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 17/25
# 5551/5551 - 7s - loss: 0.0222 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 18/25
# 5551/5551 - 7s - loss: 0.0221 - val_loss: 0.0218 - 7s/epoch - 1ms/step
# Epoch 19/25
# 5551/5551 - 7s - loss: 0.0221 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 20/25
# 5551/5551 - 7s - loss: 0.0221 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 21/25
# 5551/5551 - 7s - loss: 0.0221 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 22/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 23/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 24/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# Epoch 25/25
# 5551/5551 - 7s - loss: 0.0220 - val_loss: 0.0217 - 7s/epoch - 1ms/step
# 6939/6939 [==============================] - 6s 742us/step
# 6939/6939 [==============================] - 5s 730us/step
# 6939/6939 [==============================] - 5s 726us/step
# 6939/6939 [==============================] - 5s 730us/step
# 6939/6939 [==============================] - 5s 730us/step

# %%
import joblib

# Save the neural network models and data transformers
for i, model in enumerate(nn_model_list):
    model.save(f"nn_loan_risk_model_{i}")
joblib.dump(nn_transformer_list, "nn_data_transformer.joblib")

# Save the XGBoost models and data transformers
for i, model in enumerate(xgb_model_list):
    model.save_model(f"xgb_loan_risk_model_{i}.json")
joblib.dump(xgb_transformer_list, "xgb_data_transformer.joblib")
# Out:
# 2023-04-19 16:36:33.104505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:33.119791: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:33.137376: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:33.498034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:33.534063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:33.570690: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: nn_loan_risk_model_0/assets
# INFO:tensorflow:Assets written to: nn_loan_risk_model_0/assets
# 2023-04-19 16:36:34.226915: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:34.242029: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:34.260295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:34.631706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:34.671736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:34.712698: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: nn_loan_risk_model_1/assets
# INFO:tensorflow:Assets written to: nn_loan_risk_model_1/assets
# 2023-04-19 16:36:35.503061: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:35.520707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:35.559656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:35.920980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:35.957863: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:35.995331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: nn_loan_risk_model_2/assets
# INFO:tensorflow:Assets written to: nn_loan_risk_model_2/assets
# 2023-04-19 16:36:36.743445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:36.764295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:36.778817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:37.329666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:37.376027: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:37.425702: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: nn_loan_risk_model_3/assets
# INFO:tensorflow:Assets written to: nn_loan_risk_model_3/assets
# 2023-04-19 16:36:39.188108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:39.203771: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:39.223557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:39.485143: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,64]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:39.527729: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2023-04-19 16:36:39.596556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: nn_loan_risk_model_4/assets
# INFO:tensorflow:Assets written to: nn_loan_risk_model_4/assets
# ['xgb_data_transformer.joblib']

# %%
def compare_models(test):
    loan_grades=["A", "B", "C", "D", "E", "F", "G"]
    model_predictions = "model_predictions"
    recovered_percentage = "recovered_percentage"
    lc_prefix = "lc_"
    ty_prefix = "ty_"
    results = {}

    start_index = 0
    for grade in loan_grades:
        lc_grade = test[test["grade"] == grade]
        lc_grade_avg = round(np.mean(lc_grade[recovered_percentage]), 5)
        lc_key = lc_prefix + grade.lower()
        results[lc_key] = lc_grade_avg

        ty_grade = test.sort_values(model_predictions, axis="index", ascending=False).iloc[
            start_index : len(lc_grade) + start_index
        ]
        start_index += len(lc_grade)
        ty_grade_avg = round(np.mean(ty_grade[recovered_percentage]), 5)
        ty_key = ty_prefix + grade.lower()
        results[ty_key] = ty_grade_avg

        print(f"LendingClub gave {len(lc_grade):,} loans in the test set a(n) {grade} grade")
        print(f"Average `recovered_percentage` on LendingClub's grade {grade} loans: {lc_grade_avg}")
        print(f"Average `recovered_percentage` on Ty's grade {grade} loans (with cross-validation): {ty_grade_avg}")

    return results

results = compare_models(test)
print(results)
# Out:
# LendingClub gave 38,779 loans in the test set a(n) A grade
# Average `recovered_percentage` on LendingClub's grade A loans: 0.96021
# Average `recovered_percentage` on Ty's grade A loans (with cross-validation): 0.96471
# LendingClub gave 61,844 loans in the test set a(n) B grade
# Average `recovered_percentage` on LendingClub's grade B loans: 0.90378
# Average `recovered_percentage` on Ty's grade B loans (with cross-validation): 0.90782
# LendingClub gave 69,218 loans in the test set a(n) C grade
# Average `recovered_percentage` on LendingClub's grade C loans: 0.82924
# Average `recovered_percentage` on Ty's grade C loans (with cross-validation): 0.83769
# LendingClub gave 33,142 loans in the test set a(n) D grade
# Average `recovered_percentage` on LendingClub's grade D loans: 0.76535
# Average `recovered_percentage` on Ty's grade D loans (with cross-validation): 0.76038
# LendingClub gave 12,654 loans in the test set a(n) E grade
# Average `recovered_percentage` on LendingClub's grade E loans: 0.70825
# Average `recovered_percentage` on Ty's grade E loans (with cross-validation): 0.67021
# LendingClub gave 4,200 loans in the test set a(n) F grade
# Average `recovered_percentage` on LendingClub's grade F loans: 0.63594
# Average `recovered_percentage` on Ty's grade F loans (with cross-validation): 0.59487
# LendingClub gave 2,198 loans in the test set a(n) G grade
# Average `recovered_percentage` on LendingClub's grade G loans: 0.59235
# Average `recovered_percentage` on Ty's grade G loans (with cross-validation): 0.50564
# {'lc_a': 0.96021, 'ty_a': 0.96471, 'lc_b': 0.90378, 'ty_b': 0.90782, 'lc_c': 0.82924, 'ty_c': 0.83769, 'lc_d': 0.76535, 'ty_d': 0.76038, 'lc_e': 0.70825, 'ty_e': 0.67021, 'lc_f': 0.63594, 'ty_f': 0.59487, 'lc_g': 0.59235, 'ty_g': 0.50564}

# %%
from sklearn.metrics import mean_absolute_error

# MAE
mae = mean_absolute_error(test["recovered_percentage"], test["model_predictions"])
print("MAE:")
print(round(mae, 5))
# Out:
# MAE:
# 0.20071
