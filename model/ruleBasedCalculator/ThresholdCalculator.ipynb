# %%
import joblib
from sklearn.model_selection import train_test_split, KFold

loans = joblib.load("../data/final_model_data.joblib")

loans = loans.head(10000)

train, test = train_test_split(loans, test_size=0.2, shuffle=False)
train_nn, train_xgb, train_classification, test_nn, test_xgb, test_classification = train.copy(), train.copy(), train.copy(), test.copy(), test.copy(), test.copy()
print(f"The test set contains {len(test):,} loans.")

onehot_cols = ["term", "application_type", "home_ownership", "purpose"]
ordinal_cols = {
    "emp_length": [
        "< 1 year",
        "1 year",
        "2 years",
        "3 years",
        "4 years",
        "5 years",
        "6 years",
        "7 years",
        "8 years",
        "9 years",
        "10+ years",
    ]
}
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor


def run_pipeline_cv(data, onehot_cols, ordinal_cols, model_type="nn", batch_size=None):
    X = data.drop(columns=["recovered_percentage"])
    y = data["recovered_percentage"]

    transformer = DataFrameMapper(
        [
            (onehot_cols, OneHotEncoder(drop="if_binary", handle_unknown="ignore")),
            (
                list(ordinal_cols.keys()),
                OrdinalEncoder(categories=list(ordinal_cols.values())),
            ),
        ],
        default=StandardScaler(),
    )

    cv = KFold(n_splits=5, shuffle=True, random_state=0)

    history_list = []
    model_list = []
    transformer_list = []

    for train_idx, valid_idx in cv.split(X):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        X_train = transformer.fit_transform(X_train)
        X_valid = transformer.transform(X_valid)

        if model_type == "xgb":
            model = XGBRegressor(objective="reg:squarederror")

            model.fit(X_train, y_train)

            history_list.append(None)

        model_list.append(model)
        transformer_list.append(transformer)

    return history_list, model_list, transformer_list


def make_predictions(data, model_list, transformer_list):
    predictions_list = []

    for i in range(len(model_list)):
        model = model_list[i]
        transformer = transformer_list[i]

        X_test = transformer.transform(
            data.drop(
                columns=[
                    "recovered_percentage",
                    "issue_d",
                    "date",
                    "grade",
                    "sub_grade",
                    "expected_return",
                ]
            )
        )

        predictions = model.predict(X_test)
        predictions_list.append(predictions)

    data["model_predictions"] = np.mean(predictions_list, axis=0)

# Run the pipeline with cross-validation for XGBoost
xgb_history_list, xgb_model_list, xgb_transformer_list = run_pipeline_cv(
    train_xgb.drop(columns=["issue_d", "date", "grade", "sub_grade", "expected_return"]),
    onehot_cols,
    ordinal_cols,
    model_type="xgb",
)
# Out:
# The test set contains 2,000 loans.

# %%
from sklearn_pandas import DataFrameMapper
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_selector as selector

train, test = train_classification, test_classification
print(f"The test set contains {len(test):,} loans.")
onehot_cols = ["term", "application_type", "home_ownership", "purpose"]
ordinal_cols = {
    "emp_length": [
        "< 1 year",
        "1 year",
        "2 years",
        "3 years",
        "4 years",
        "5 years",
        "6 years",
        "7 years",
        "8 years",
        "9 years",
        "10+ years",
    ],
}

def run_pipeline_cv_nn(
        data,
        onehot_cols,
        ordinal_cols,
        batch_size,
):
    X = data.drop(
        columns=["issue_d", "date", "grade", "grade_encoded", "sub_grade", "recovered_percentage", "expected_return"])
    y = data["grade_encoded"]

    transformer = DataFrameMapper(
        [
            (onehot_cols, OneHotEncoder(drop="if_binary", handle_unknown="error")),
            (
                list(ordinal_cols.keys()),
                OrdinalEncoder(categories=list(ordinal_cols.values())),
            ),
        ],
        default=StandardScaler(),
    )

    cv = KFold(n_splits=5, shuffle=True, random_state=0)

    history_list = []
    model_list = []
    transformer_list = []

    for train_idx, valid_idx in cv.split(X):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        print(X_train.keys())
        X_train = transformer.fit_transform(X_train)
        X_valid = transformer.transform(X_valid)

        input_nodes = X_train.shape[1]

        # Define the model architecture
        model = Sequential()
        model.add(Input(shape=input_nodes))
        model.add(Dense(64, activation="relu"))
        model.add(Dropout(0.3, seed=0))
        model.add(Dense(32, activation="relu"))
        model.add(Dropout(0.3, seed=1))
        model.add(Dense(16, activation="relu"))
        model.add(Dropout(0.3, seed=1))
        model.add(Dense(7, activation="softmax"))
        model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

        # # Define the EarlyStopping callback
        # early_stopping = EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

        history = model.fit(
            X_train,
            y_train,
            batch_size=batch_size,
            epochs=300,
            validation_data=(X_valid, y_valid),
            verbose=2,
            # callbacks=[early_stopping],  # Add the EarlyStopping callback
        )

        history_list.append(history.history)
        model_list.append(model)
        transformer_list.append(transformer)

    return history_list, model_list, transformer_list


# Encode loan grades as integers
grade_encoder = {
    "A": 0,
    "B": 1,
    "C": 2,
    "D": 3,
    "E": 4,
    "F": 5,
    "G": 6,
}
train["grade_encoded"] = train["grade"].apply(lambda x: grade_encoder[x])
test["grade_encoded"] = test["grade"].apply(lambda x: grade_encoder[x])

# Run the pipeline with cross-validation
nn_history_list, nn_model_list, nn_transformer_list = run_pipeline_cv_nn(
    train,
    onehot_cols,
    ordinal_cols,
    batch_size=128,
)


def run_pipeline_cv_svm(
        data,
        onehot_cols,
        ordinal_cols,
):
    X = data.drop(
        columns=["issue_d", "date", "grade", "grade_encoded", "sub_grade", "recovered_percentage", "expected_return"])
    y = data["grade_encoded"]

    transformer = DataFrameMapper(
        [
            (onehot_cols, OneHotEncoder(drop="if_binary", handle_unknown="error")),
            (
                list(ordinal_cols.keys()),
                OrdinalEncoder(categories=list(ordinal_cols.values())),
            ),
        ],
        default=StandardScaler(),
    )

    cv = KFold(n_splits=5, shuffle=True, random_state=0)

    history_list = []
    model_list = []
    transformer_list = []

    for train_idx, valid_idx in cv.split(X):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        print("before trans: ")
        print(X_train.shape)
        print(X_valid.shape)
        X_train = transformer.fit_transform(X_train)
        X_valid = transformer.transform(X_valid)

        print("after trans: ")
        print(X_train.shape)
        print(X_valid.shape)

        # Define the parameter grid to search
        param_grid = {
            'C': [0.1, 1, 10],
            'gamma': [0.01, 0.1, 1]
        }

        # Define the SVM model
        svm = SVC(kernel='linear')

        # Use GridSearchCV to search for the best hyperparameters
        grid_search = GridSearchCV(svm, param_grid, cv=5, n_jobs=-1)
        grid_search.fit(X_train, y_train)

        # Print the best hyperparameters and their corresponding score
        print("Best hyperparameters:", grid_search.best_params_)
        print("Best score:", grid_search.best_score_)

        history_list.append(None)
        model_list.append(grid_search.best_estimator_)
        transformer_list.append(transformer)

    return history_list, model_list, transformer_list


# Run the pipeline with cross-validation
svm_history_list, svm_model_list, svm_transformer_list = run_pipeline_cv_svm(
    train,
    onehot_cols,
    ordinal_cols,
)

def run_pipeline_cv_dt(data, onehot_cols, ordinal_cols):
    X = data.drop(
        columns=["issue_d", "date", "grade", "grade_encoded", "sub_grade", "recovered_percentage", "expected_return"])
    y = data["grade_encoded"]

    transformer = ColumnTransformer(
        [
            ('onehot', OneHotEncoder(drop="if_binary", handle_unknown="error"), onehot_cols),
            ('ordinal', OrdinalEncoder(categories=list(ordinal_cols.values())), list(ordinal_cols.keys())),
            ('imputer', SimpleImputer(strategy='median'), selector(dtype_include='number'))
        ],
        remainder=StandardScaler()
    )

    cv = KFold(n_splits=5, shuffle=True, random_state=0)

    history_list = []
    model_list = []
    transformer_list = []

    for train_idx, valid_idx in cv.split(X):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        pipeline = Pipeline([
            ('preprocess', transformer),
            ('model', DecisionTreeClassifier())
        ])

        pipeline.fit(X_train, y_train)

        y_pred = pipeline.predict(X_valid)

        accuracy = accuracy_score(y_valid, y_pred)
        precision = precision_score(y_valid, y_pred, average='weighted')
        recall = recall_score(y_valid, y_pred, average='weighted')
        f1 = f1_score(y_valid, y_pred, average='weighted')

        history_list.append({
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1
        })
        model_list.append(pipeline)
        transformer_list.append(transformer)

    return history_list, model_list, transformer_list


# Run the pipeline with cross-validation for Decision Trees
dt_history_list, dt_model_list, dt_transformer_list = run_pipeline_cv_dt(
    train,
    onehot_cols,
    ordinal_cols,
)

from sklearn.metrics import accuracy_score
from scipy.stats import mode

# Load the test set and extract the true labels
X_test = test.drop(
    columns=["issue_d", "date", "grade", "grade_encoded", "sub_grade", "recovered_percentage", "expected_return"])
y_test = test["grade_encoded"]

# Make predictions using the ensemble model
predictions_list_nn = []
predictions_list = []

for i in range(len(nn_model_list)):
    transformer = nn_transformer_list[i]
    model = nn_model_list[i]

    X_test_transformed = transformer.transform(X_test)
    y_pred = model.predict(X_test_transformed)
    predictions_list_nn.append(y_pred)

for i in range(len(svm_model_list)):
    transformer = svm_transformer_list[i]
    model = svm_model_list[i]

    X_test_transformed = transformer.transform(X_test)
    y_pred = model.predict(X_test_transformed)
    predictions_list.append(y_pred)

for model in dt_model_list:
    y_pred = model.predict(X_test)
    predictions_list.append(y_pred)

# Convert the predictions to class labels
class_predictions_list = [np.argmax(predictions, axis=1) for predictions in predictions_list_nn]

for predictions in predictions_list:
    class_predictions_list.append(predictions)

# Combine the predictions from each model
class_predictions_array = np.array(class_predictions_list)

# Take the majority vote for each test sample
final_predictions = mode(class_predictions_array, axis=0).mode[0]
# Out:
# The test set contains 2,000 loans.
# Index(['loan_amnt', 'term', 'emp_length', 'home_ownership', 'annual_inc',
#        'purpose', 'dti', 'delinq_2yrs', 'cr_hist_age_mths', 'fico_range_low',
#        'fico_range_high', 'inq_last_6mths', 'inv_mths_since_last_delinq',
#        'inv_mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'collections_12_mths_ex_med',
#        'inv_mths_since_last_major_derog', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'total_rev_hi_lim', 'acc_open_past_24mths',
#        'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op',
#        'inv_mo_sin_rcnt_rev_tl_op', 'inv_mo_sin_rcnt_tl', 'mort_acc',
#        'inv_mths_since_recent_bc', 'inv_mths_since_recent_bc_dlq',
#        'inv_mths_since_recent_inq', 'inv_mths_since_recent_revol_delinq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m',
#        'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',
#        'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies',
#        'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object')
# Epoch 1/300
# 50/50 - 0s - loss: 1.7737 - accuracy: 0.2859 - val_loss: 1.5142 - val_accuracy: 0.3700 - 234ms/epoch - 5ms/step
# Epoch 2/300
# 50/50 - 0s - loss: 1.5639 - accuracy: 0.3556 - val_loss: 1.3451 - val_accuracy: 0.4550 - 40ms/epoch - 798us/step
# Epoch 3/300
# 50/50 - 0s - loss: 1.4411 - accuracy: 0.4092 - val_loss: 1.2427 - val_accuracy: 0.4800 - 45ms/epoch - 904us/step
# Epoch 4/300
# 50/50 - 0s - loss: 1.3468 - accuracy: 0.4444 - val_loss: 1.1596 - val_accuracy: 0.5138 - 47ms/epoch - 946us/step
# Epoch 5/300
# 50/50 - 0s - loss: 1.2643 - accuracy: 0.4802 - val_loss: 1.0886 - val_accuracy: 0.5512 - 47ms/epoch - 944us/step
# Epoch 6/300
# 50/50 - 0s - loss: 1.2013 - accuracy: 0.5038 - val_loss: 1.0198 - val_accuracy: 0.5700 - 47ms/epoch - 933us/step
# Epoch 7/300
# 50/50 - 0s - loss: 1.1361 - accuracy: 0.5280 - val_loss: 0.9684 - val_accuracy: 0.6025 - 80ms/epoch - 2ms/step
# Epoch 8/300
# 50/50 - 0s - loss: 1.0888 - accuracy: 0.5483 - val_loss: 0.9131 - val_accuracy: 0.6494 - 50ms/epoch - 994us/step
# Epoch 9/300
# 50/50 - 0s - loss: 1.0277 - accuracy: 0.5661 - val_loss: 0.8553 - val_accuracy: 0.6744 - 45ms/epoch - 902us/step
# Epoch 10/300
# 50/50 - 0s - loss: 0.9746 - accuracy: 0.5817 - val_loss: 0.8138 - val_accuracy: 0.6900 - 44ms/epoch - 876us/step
# Epoch 11/300
# 50/50 - 0s - loss: 0.9388 - accuracy: 0.6031 - val_loss: 0.7836 - val_accuracy: 0.7025 - 45ms/epoch - 904us/step
# Epoch 12/300
# 50/50 - 0s - loss: 0.9028 - accuracy: 0.6177 - val_loss: 0.7468 - val_accuracy: 0.7069 - 64ms/epoch - 1ms/step
# Epoch 13/300
# 50/50 - 0s - loss: 0.8820 - accuracy: 0.6328 - val_loss: 0.7213 - val_accuracy: 0.7194 - 46ms/epoch - 924us/step
# Epoch 14/300
# 50/50 - 0s - loss: 0.8460 - accuracy: 0.6420 - val_loss: 0.6961 - val_accuracy: 0.7300 - 45ms/epoch - 890us/step
# Epoch 15/300
# 50/50 - 0s - loss: 0.8390 - accuracy: 0.6516 - val_loss: 0.6901 - val_accuracy: 0.7331 - 45ms/epoch - 892us/step
# Epoch 16/300
# 50/50 - 0s - loss: 0.8163 - accuracy: 0.6498 - val_loss: 0.6831 - val_accuracy: 0.7319 - 45ms/epoch - 909us/step
# Epoch 17/300
# 50/50 - 0s - loss: 0.8077 - accuracy: 0.6589 - val_loss: 0.6814 - val_accuracy: 0.7250 - 44ms/epoch - 888us/step
# Epoch 18/300
# 50/50 - 0s - loss: 0.7844 - accuracy: 0.6634 - val_loss: 0.6470 - val_accuracy: 0.7406 - 46ms/epoch - 920us/step
# Epoch 19/300
# 50/50 - 0s - loss: 0.7749 - accuracy: 0.6737 - val_loss: 0.6413 - val_accuracy: 0.7387 - 46ms/epoch - 927us/step
# Epoch 20/300
# 50/50 - 0s - loss: 0.7461 - accuracy: 0.6842 - val_loss: 0.6270 - val_accuracy: 0.7506 - 48ms/epoch - 956us/step
# Epoch 21/300
# 50/50 - 0s - loss: 0.7647 - accuracy: 0.6875 - val_loss: 0.6210 - val_accuracy: 0.7381 - 46ms/epoch - 920us/step
# Epoch 22/300
# 50/50 - 0s - loss: 0.7356 - accuracy: 0.6900 - val_loss: 0.6106 - val_accuracy: 0.7481 - 45ms/epoch - 908us/step
# Epoch 23/300
# 50/50 - 0s - loss: 0.7343 - accuracy: 0.7008 - val_loss: 0.6030 - val_accuracy: 0.7550 - 46ms/epoch - 923us/step
# Epoch 24/300
# 50/50 - 0s - loss: 0.7214 - accuracy: 0.7027 - val_loss: 0.6010 - val_accuracy: 0.7631 - 47ms/epoch - 932us/step
# Epoch 25/300
# 50/50 - 0s - loss: 0.7107 - accuracy: 0.7056 - val_loss: 0.5969 - val_accuracy: 0.7494 - 45ms/epoch - 904us/step
# Epoch 26/300
# 50/50 - 0s - loss: 0.6992 - accuracy: 0.7147 - val_loss: 0.5850 - val_accuracy: 0.7513 - 44ms/epoch - 889us/step
# Epoch 27/300
# 50/50 - 0s - loss: 0.6862 - accuracy: 0.7216 - val_loss: 0.5878 - val_accuracy: 0.7681 - 48ms/epoch - 952us/step
# Epoch 28/300
# 50/50 - 0s - loss: 0.6746 - accuracy: 0.7266 - val_loss: 0.5698 - val_accuracy: 0.7844 - 47ms/epoch - 935us/step
# Epoch 29/300
# 50/50 - 0s - loss: 0.6798 - accuracy: 0.7220 - val_loss: 0.5795 - val_accuracy: 0.7613 - 46ms/epoch - 925us/step
# Epoch 30/300
# 50/50 - 0s - loss: 0.6651 - accuracy: 0.7253 - val_loss: 0.5677 - val_accuracy: 0.7631 - 45ms/epoch - 909us/step
# Epoch 31/300
# 50/50 - 0s - loss: 0.6563 - accuracy: 0.7344 - val_loss: 0.5496 - val_accuracy: 0.7769 - 46ms/epoch - 914us/step
# Epoch 32/300
# 50/50 - 0s - loss: 0.6623 - accuracy: 0.7380 - val_loss: 0.5579 - val_accuracy: 0.7700 - 45ms/epoch - 898us/step
# Epoch 33/300
# 50/50 - 0s - loss: 0.6437 - accuracy: 0.7367 - val_loss: 0.5589 - val_accuracy: 0.7731 - 45ms/epoch - 894us/step
# Epoch 34/300
# 50/50 - 0s - loss: 0.6261 - accuracy: 0.7447 - val_loss: 0.5402 - val_accuracy: 0.7900 - 44ms/epoch - 885us/step
# Epoch 35/300
# 50/50 - 0s - loss: 0.6302 - accuracy: 0.7528 - val_loss: 0.5427 - val_accuracy: 0.7775 - 43ms/epoch - 860us/step
# Epoch 36/300
# 50/50 - 0s - loss: 0.6201 - accuracy: 0.7497 - val_loss: 0.5417 - val_accuracy: 0.7781 - 44ms/epoch - 874us/step
# Epoch 37/300
# 50/50 - 0s - loss: 0.6159 - accuracy: 0.7547 - val_loss: 0.5365 - val_accuracy: 0.7769 - 44ms/epoch - 879us/step
# Epoch 38/300
# 50/50 - 0s - loss: 0.6192 - accuracy: 0.7531 - val_loss: 0.5385 - val_accuracy: 0.7756 - 44ms/epoch - 884us/step
# Epoch 39/300
# 50/50 - 0s - loss: 0.6225 - accuracy: 0.7484 - val_loss: 0.5490 - val_accuracy: 0.7775 - 45ms/epoch - 891us/step
# Epoch 40/300
# 50/50 - 0s - loss: 0.6021 - accuracy: 0.7594 - val_loss: 0.5343 - val_accuracy: 0.8019 - 45ms/epoch - 894us/step
# Epoch 41/300
# 50/50 - 0s - loss: 0.6050 - accuracy: 0.7603 - val_loss: 0.5387 - val_accuracy: 0.7856 - 44ms/epoch - 876us/step
# Epoch 42/300
# 50/50 - 0s - loss: 0.5917 - accuracy: 0.7641 - val_loss: 0.5420 - val_accuracy: 0.7812 - 45ms/epoch - 893us/step
# Epoch 43/300
# 50/50 - 0s - loss: 0.5938 - accuracy: 0.7584 - val_loss: 0.5329 - val_accuracy: 0.7731 - 47ms/epoch - 947us/step
# Epoch 44/300
# 50/50 - 0s - loss: 0.5935 - accuracy: 0.7584 - val_loss: 0.5239 - val_accuracy: 0.7750 - 47ms/epoch - 931us/step
# Epoch 45/300
# 50/50 - 0s - loss: 0.5818 - accuracy: 0.7686 - val_loss: 0.5202 - val_accuracy: 0.7744 - 45ms/epoch - 892us/step
# Epoch 46/300
# 50/50 - 0s - loss: 0.5746 - accuracy: 0.7755 - val_loss: 0.5262 - val_accuracy: 0.7975 - 45ms/epoch - 906us/step
# Epoch 47/300
# 50/50 - 0s - loss: 0.5828 - accuracy: 0.7680 - val_loss: 0.5199 - val_accuracy: 0.7819 - 46ms/epoch - 925us/step
# Epoch 48/300
# 50/50 - 0s - loss: 0.5812 - accuracy: 0.7759 - val_loss: 0.5255 - val_accuracy: 0.7894 - 46ms/epoch - 912us/step
# Epoch 49/300
# 50/50 - 0s - loss: 0.5593 - accuracy: 0.7809 - val_loss: 0.5194 - val_accuracy: 0.7937 - 46ms/epoch - 918us/step
# Epoch 50/300
# 50/50 - 0s - loss: 0.5723 - accuracy: 0.7714 - val_loss: 0.5209 - val_accuracy: 0.7937 - 44ms/epoch - 887us/step
# Epoch 51/300
# 50/50 - 0s - loss: 0.5644 - accuracy: 0.7783 - val_loss: 0.5183 - val_accuracy: 0.7962 - 44ms/epoch - 878us/step
# Epoch 52/300
# 50/50 - 0s - loss: 0.5567 - accuracy: 0.7819 - val_loss: 0.5163 - val_accuracy: 0.7944 - 43ms/epoch - 863us/step
# Epoch 53/300
# 50/50 - 0s - loss: 0.5589 - accuracy: 0.7695 - val_loss: 0.5202 - val_accuracy: 0.7862 - 43ms/epoch - 868us/step
# Epoch 54/300
# 50/50 - 0s - loss: 0.5487 - accuracy: 0.7758 - val_loss: 0.5280 - val_accuracy: 0.7975 - 44ms/epoch - 882us/step
# Epoch 55/300
# 50/50 - 0s - loss: 0.5392 - accuracy: 0.7889 - val_loss: 0.5281 - val_accuracy: 0.7850 - 44ms/epoch - 884us/step
# Epoch 56/300
# 50/50 - 0s - loss: 0.5345 - accuracy: 0.7839 - val_loss: 0.5197 - val_accuracy: 0.8031 - 44ms/epoch - 871us/step
# Epoch 57/300
# 50/50 - 0s - loss: 0.5444 - accuracy: 0.7817 - val_loss: 0.5164 - val_accuracy: 0.7862 - 44ms/epoch - 877us/step
# Epoch 58/300
# 50/50 - 0s - loss: 0.5357 - accuracy: 0.7880 - val_loss: 0.5146 - val_accuracy: 0.7931 - 44ms/epoch - 886us/step
# Epoch 59/300
# 50/50 - 0s - loss: 0.5534 - accuracy: 0.7756 - val_loss: 0.5204 - val_accuracy: 0.7875 - 44ms/epoch - 884us/step
# Epoch 60/300
# 50/50 - 0s - loss: 0.5280 - accuracy: 0.7933 - val_loss: 0.5097 - val_accuracy: 0.7875 - 45ms/epoch - 898us/step
# Epoch 61/300
# 50/50 - 0s - loss: 0.5236 - accuracy: 0.7934 - val_loss: 0.5093 - val_accuracy: 0.7956 - 44ms/epoch - 876us/step
# Epoch 62/300
# 50/50 - 0s - loss: 0.5262 - accuracy: 0.8002 - val_loss: 0.5108 - val_accuracy: 0.7856 - 44ms/epoch - 872us/step
# Epoch 63/300
# 50/50 - 0s - loss: 0.5244 - accuracy: 0.7906 - val_loss: 0.5219 - val_accuracy: 0.7894 - 43ms/epoch - 860us/step
# Epoch 64/300
# 50/50 - 0s - loss: 0.5275 - accuracy: 0.7911 - val_loss: 0.5120 - val_accuracy: 0.7906 - 43ms/epoch - 865us/step
# Epoch 65/300
# 50/50 - 0s - loss: 0.5162 - accuracy: 0.7998 - val_loss: 0.5162 - val_accuracy: 0.7919 - 44ms/epoch - 883us/step
# Epoch 66/300
# 50/50 - 0s - loss: 0.5084 - accuracy: 0.7984 - val_loss: 0.5108 - val_accuracy: 0.7931 - 46ms/epoch - 912us/step
# Epoch 67/300
# 50/50 - 0s - loss: 0.5196 - accuracy: 0.7981 - val_loss: 0.5192 - val_accuracy: 0.7856 - 45ms/epoch - 897us/step
# Epoch 68/300
# 50/50 - 0s - loss: 0.5181 - accuracy: 0.7980 - val_loss: 0.5161 - val_accuracy: 0.7956 - 44ms/epoch - 887us/step
# Epoch 69/300
# 50/50 - 0s - loss: 0.4997 - accuracy: 0.8058 - val_loss: 0.5155 - val_accuracy: 0.7975 - 44ms/epoch - 883us/step
# Epoch 70/300
# 50/50 - 0s - loss: 0.5105 - accuracy: 0.7994 - val_loss: 0.5101 - val_accuracy: 0.7925 - 43ms/epoch - 857us/step
# Epoch 71/300
# 50/50 - 0s - loss: 0.4918 - accuracy: 0.8064 - val_loss: 0.5151 - val_accuracy: 0.7919 - 44ms/epoch - 886us/step
# Epoch 72/300
# 50/50 - 0s - loss: 0.5007 - accuracy: 0.8031 - val_loss: 0.5166 - val_accuracy: 0.7975 - 44ms/epoch - 886us/step
# Epoch 73/300
# 50/50 - 0s - loss: 0.5036 - accuracy: 0.8059 - val_loss: 0.5097 - val_accuracy: 0.7956 - 44ms/epoch - 880us/step
# Epoch 74/300
# 50/50 - 0s - loss: 0.5034 - accuracy: 0.8022 - val_loss: 0.5226 - val_accuracy: 0.7931 - 45ms/epoch - 908us/step
# Epoch 75/300
# 50/50 - 0s - loss: 0.5063 - accuracy: 0.8059 - val_loss: 0.5061 - val_accuracy: 0.7981 - 46ms/epoch - 913us/step
# Epoch 76/300
# 50/50 - 0s - loss: 0.5015 - accuracy: 0.8036 - val_loss: 0.5133 - val_accuracy: 0.8075 - 43ms/epoch - 863us/step
# Epoch 77/300
# 50/50 - 0s - loss: 0.5062 - accuracy: 0.8042 - val_loss: 0.5236 - val_accuracy: 0.7831 - 42ms/epoch - 839us/step
# Epoch 78/300
# 50/50 - 0s - loss: 0.4735 - accuracy: 0.8128 - val_loss: 0.5132 - val_accuracy: 0.7844 - 44ms/epoch - 873us/step
# Epoch 79/300
# 50/50 - 0s - loss: 0.4933 - accuracy: 0.8092 - val_loss: 0.5148 - val_accuracy: 0.7931 - 43ms/epoch - 869us/step
# Epoch 80/300
# 50/50 - 0s - loss: 0.4781 - accuracy: 0.8138 - val_loss: 0.5146 - val_accuracy: 0.7906 - 46ms/epoch - 922us/step
# Epoch 81/300
# 50/50 - 0s - loss: 0.4791 - accuracy: 0.8116 - val_loss: 0.5245 - val_accuracy: 0.7750 - 45ms/epoch - 890us/step
# Epoch 82/300
# 50/50 - 0s - loss: 0.4784 - accuracy: 0.8112 - val_loss: 0.5041 - val_accuracy: 0.7994 - 45ms/epoch - 891us/step
# Epoch 83/300
# 50/50 - 0s - loss: 0.4726 - accuracy: 0.8209 - val_loss: 0.5153 - val_accuracy: 0.7981 - 45ms/epoch - 908us/step
# Epoch 84/300
# 50/50 - 0s - loss: 0.4739 - accuracy: 0.8205 - val_loss: 0.5024 - val_accuracy: 0.7937 - 45ms/epoch - 891us/step
# Epoch 85/300
# 50/50 - 0s - loss: 0.4871 - accuracy: 0.8119 - val_loss: 0.5129 - val_accuracy: 0.7950 - 45ms/epoch - 891us/step
# Epoch 86/300
# 50/50 - 0s - loss: 0.4731 - accuracy: 0.8195 - val_loss: 0.4999 - val_accuracy: 0.7925 - 45ms/epoch - 892us/step
# Epoch 87/300
# 50/50 - 0s - loss: 0.4641 - accuracy: 0.8203 - val_loss: 0.5016 - val_accuracy: 0.8019 - 44ms/epoch - 890us/step
# Epoch 88/300
# 50/50 - 0s - loss: 0.4755 - accuracy: 0.8202 - val_loss: 0.4874 - val_accuracy: 0.8019 - 46ms/epoch - 914us/step
# Epoch 89/300
# 50/50 - 0s - loss: 0.4778 - accuracy: 0.8198 - val_loss: 0.5075 - val_accuracy: 0.8006 - 44ms/epoch - 886us/step
# Epoch 90/300
# 50/50 - 0s - loss: 0.4645 - accuracy: 0.8208 - val_loss: 0.4994 - val_accuracy: 0.7950 - 44ms/epoch - 888us/step
# Epoch 91/300
# 50/50 - 0s - loss: 0.4775 - accuracy: 0.8198 - val_loss: 0.4938 - val_accuracy: 0.8006 - 44ms/epoch - 879us/step
# Epoch 92/300
# 50/50 - 0s - loss: 0.4484 - accuracy: 0.8283 - val_loss: 0.4985 - val_accuracy: 0.7969 - 44ms/epoch - 882us/step
# Epoch 93/300
# 50/50 - 0s - loss: 0.4615 - accuracy: 0.8272 - val_loss: 0.4968 - val_accuracy: 0.8056 - 45ms/epoch - 891us/step
# Epoch 94/300
# 50/50 - 0s - loss: 0.4619 - accuracy: 0.8183 - val_loss: 0.4938 - val_accuracy: 0.8000 - 44ms/epoch - 877us/step
# Epoch 95/300
# 50/50 - 0s - loss: 0.4609 - accuracy: 0.8234 - val_loss: 0.4984 - val_accuracy: 0.8031 - 44ms/epoch - 873us/step
# Epoch 96/300
# 50/50 - 0s - loss: 0.4563 - accuracy: 0.8209 - val_loss: 0.5175 - val_accuracy: 0.7969 - 44ms/epoch - 882us/step
# Epoch 97/300
# 50/50 - 0s - loss: 0.4436 - accuracy: 0.8303 - val_loss: 0.5227 - val_accuracy: 0.7925 - 44ms/epoch - 886us/step
# Epoch 98/300
# 50/50 - 0s - loss: 0.4534 - accuracy: 0.8308 - val_loss: 0.5084 - val_accuracy: 0.8050 - 45ms/epoch - 906us/step
# Epoch 99/300
# 50/50 - 0s - loss: 0.4572 - accuracy: 0.8213 - val_loss: 0.5173 - val_accuracy: 0.7906 - 45ms/epoch - 907us/step
# Epoch 100/300
# 50/50 - 0s - loss: 0.4463 - accuracy: 0.8292 - val_loss: 0.5269 - val_accuracy: 0.7869 - 45ms/epoch - 893us/step
# Epoch 101/300
# 50/50 - 0s - loss: 0.4499 - accuracy: 0.8267 - val_loss: 0.5234 - val_accuracy: 0.7925 - 46ms/epoch - 910us/step
# Epoch 102/300
# 50/50 - 0s - loss: 0.4653 - accuracy: 0.8261 - val_loss: 0.5142 - val_accuracy: 0.7944 - 45ms/epoch - 893us/step
# Epoch 103/300
# 50/50 - 0s - loss: 0.4480 - accuracy: 0.8277 - val_loss: 0.5253 - val_accuracy: 0.7819 - 44ms/epoch - 884us/step
# Epoch 104/300
# 50/50 - 0s - loss: 0.4567 - accuracy: 0.8222 - val_loss: 0.5145 - val_accuracy: 0.7912 - 45ms/epoch - 900us/step
# Epoch 105/300
# 50/50 - 0s - loss: 0.4520 - accuracy: 0.8216 - val_loss: 0.5031 - val_accuracy: 0.7975 - 44ms/epoch - 876us/step
# Epoch 106/300
# 50/50 - 0s - loss: 0.4404 - accuracy: 0.8327 - val_loss: 0.4982 - val_accuracy: 0.8012 - 45ms/epoch - 904us/step
# Epoch 107/300
# 50/50 - 0s - loss: 0.4445 - accuracy: 0.8345 - val_loss: 0.5043 - val_accuracy: 0.7994 - 44ms/epoch - 884us/step
# Epoch 108/300
# 50/50 - 0s - loss: 0.4464 - accuracy: 0.8252 - val_loss: 0.5027 - val_accuracy: 0.8012 - 45ms/epoch - 891us/step
# Epoch 109/300
# 50/50 - 0s - loss: 0.4441 - accuracy: 0.8342 - val_loss: 0.5032 - val_accuracy: 0.7981 - 45ms/epoch - 910us/step
# Epoch 110/300
# 50/50 - 0s - loss: 0.4377 - accuracy: 0.8309 - val_loss: 0.5040 - val_accuracy: 0.7981 - 46ms/epoch - 925us/step
# Epoch 111/300
# 50/50 - 0s - loss: 0.4470 - accuracy: 0.8314 - val_loss: 0.5022 - val_accuracy: 0.7987 - 45ms/epoch - 904us/step
# Epoch 112/300
# 50/50 - 0s - loss: 0.4336 - accuracy: 0.8284 - val_loss: 0.4989 - val_accuracy: 0.7900 - 45ms/epoch - 893us/step
# Epoch 113/300
# 50/50 - 0s - loss: 0.4267 - accuracy: 0.8375 - val_loss: 0.5145 - val_accuracy: 0.7944 - 44ms/epoch - 879us/step
# Epoch 114/300
# 50/50 - 0s - loss: 0.4429 - accuracy: 0.8298 - val_loss: 0.5133 - val_accuracy: 0.8012 - 45ms/epoch - 902us/step
# Epoch 115/300
# 50/50 - 0s - loss: 0.4437 - accuracy: 0.8319 - val_loss: 0.5285 - val_accuracy: 0.7981 - 45ms/epoch - 907us/step
# Epoch 116/300
# 50/50 - 0s - loss: 0.4410 - accuracy: 0.8388 - val_loss: 0.5161 - val_accuracy: 0.7956 - 46ms/epoch - 917us/step
# Epoch 117/300
# 50/50 - 0s - loss: 0.4226 - accuracy: 0.8345 - val_loss: 0.5132 - val_accuracy: 0.7994 - 45ms/epoch - 892us/step
# Epoch 118/300
# 50/50 - 0s - loss: 0.4355 - accuracy: 0.8386 - val_loss: 0.5235 - val_accuracy: 0.7987 - 44ms/epoch - 887us/step
# Epoch 119/300
# 50/50 - 0s - loss: 0.4215 - accuracy: 0.8383 - val_loss: 0.5077 - val_accuracy: 0.8000 - 42ms/epoch - 849us/step
# Epoch 120/300
# 50/50 - 0s - loss: 0.4358 - accuracy: 0.8302 - val_loss: 0.5056 - val_accuracy: 0.7987 - 45ms/epoch - 890us/step
# Epoch 121/300
# 50/50 - 0s - loss: 0.4300 - accuracy: 0.8369 - val_loss: 0.5248 - val_accuracy: 0.7962 - 44ms/epoch - 883us/step
# Epoch 122/300
# 50/50 - 0s - loss: 0.4225 - accuracy: 0.8402 - val_loss: 0.5049 - val_accuracy: 0.7981 - 45ms/epoch - 893us/step
# Epoch 123/300
# 50/50 - 0s - loss: 0.4347 - accuracy: 0.8319 - val_loss: 0.5085 - val_accuracy: 0.7981 - 45ms/epoch - 899us/step
# Epoch 124/300
# 50/50 - 0s - loss: 0.4354 - accuracy: 0.8381 - val_loss: 0.5145 - val_accuracy: 0.7937 - 44ms/epoch - 884us/step
# Epoch 125/300
# 50/50 - 0s - loss: 0.4362 - accuracy: 0.8380 - val_loss: 0.5330 - val_accuracy: 0.7950 - 45ms/epoch - 893us/step
# Epoch 126/300
# 50/50 - 0s - loss: 0.4241 - accuracy: 0.8431 - val_loss: 0.5104 - val_accuracy: 0.8037 - 45ms/epoch - 903us/step
# Epoch 127/300
# 50/50 - 0s - loss: 0.4339 - accuracy: 0.8347 - val_loss: 0.5061 - val_accuracy: 0.7956 - 49ms/epoch - 976us/step
# Epoch 128/300
# 50/50 - 0s - loss: 0.4171 - accuracy: 0.8462 - val_loss: 0.5066 - val_accuracy: 0.7981 - 44ms/epoch - 873us/step
# Epoch 129/300
# 50/50 - 0s - loss: 0.4266 - accuracy: 0.8378 - val_loss: 0.5206 - val_accuracy: 0.7900 - 44ms/epoch - 886us/step
# Epoch 130/300
# 50/50 - 0s - loss: 0.4237 - accuracy: 0.8380 - val_loss: 0.5379 - val_accuracy: 0.7894 - 43ms/epoch - 850us/step
# Epoch 131/300
# 50/50 - 0s - loss: 0.4212 - accuracy: 0.8356 - val_loss: 0.5230 - val_accuracy: 0.7944 - 38ms/epoch - 754us/step
# Epoch 132/300
# 50/50 - 0s - loss: 0.4230 - accuracy: 0.8403 - val_loss: 0.5303 - val_accuracy: 0.7937 - 39ms/epoch - 778us/step
# Epoch 133/300
# 50/50 - 0s - loss: 0.4224 - accuracy: 0.8383 - val_loss: 0.5342 - val_accuracy: 0.7981 - 39ms/epoch - 787us/step
# Epoch 134/300
# 50/50 - 0s - loss: 0.4180 - accuracy: 0.8381 - val_loss: 0.5411 - val_accuracy: 0.7962 - 40ms/epoch - 805us/step
# Epoch 135/300
# 50/50 - 0s - loss: 0.4277 - accuracy: 0.8355 - val_loss: 0.5357 - val_accuracy: 0.7931 - 37ms/epoch - 750us/step
# Epoch 136/300
# 50/50 - 0s - loss: 0.4204 - accuracy: 0.8413 - val_loss: 0.5109 - val_accuracy: 0.7987 - 40ms/epoch - 801us/step
# Epoch 137/300
# 50/50 - 0s - loss: 0.4210 - accuracy: 0.8405 - val_loss: 0.5239 - val_accuracy: 0.7962 - 39ms/epoch - 771us/step
# Epoch 138/300
# 50/50 - 0s - loss: 0.4195 - accuracy: 0.8402 - val_loss: 0.5420 - val_accuracy: 0.7944 - 41ms/epoch - 820us/step
# Epoch 139/300
# 50/50 - 0s - loss: 0.4243 - accuracy: 0.8403 - val_loss: 0.5204 - val_accuracy: 0.7981 - 38ms/epoch - 756us/step
# Epoch 140/300
# 50/50 - 0s - loss: 0.4052 - accuracy: 0.8453 - val_loss: 0.5170 - val_accuracy: 0.8044 - 37ms/epoch - 747us/step
# Epoch 141/300
# 50/50 - 0s - loss: 0.4037 - accuracy: 0.8445 - val_loss: 0.5082 - val_accuracy: 0.8025 - 38ms/epoch - 759us/step
# Epoch 142/300
# 50/50 - 0s - loss: 0.4174 - accuracy: 0.8419 - val_loss: 0.5491 - val_accuracy: 0.7919 - 45ms/epoch - 900us/step
# Epoch 143/300
# 50/50 - 0s - loss: 0.4127 - accuracy: 0.8420 - val_loss: 0.5170 - val_accuracy: 0.8012 - 40ms/epoch - 810us/step
# Epoch 144/300
# 50/50 - 0s - loss: 0.4135 - accuracy: 0.8498 - val_loss: 0.5136 - val_accuracy: 0.8062 - 42ms/epoch - 843us/step
# Epoch 145/300
# 50/50 - 0s - loss: 0.4117 - accuracy: 0.8428 - val_loss: 0.5163 - val_accuracy: 0.7994 - 43ms/epoch - 859us/step
# Epoch 146/300
# 50/50 - 0s - loss: 0.4121 - accuracy: 0.8508 - val_loss: 0.5071 - val_accuracy: 0.7887 - 43ms/epoch - 853us/step
# Epoch 147/300
# 50/50 - 0s - loss: 0.4128 - accuracy: 0.8442 - val_loss: 0.5305 - val_accuracy: 0.8056 - 68ms/epoch - 1ms/step
# Epoch 148/300
# 50/50 - 0s - loss: 0.4046 - accuracy: 0.8466 - val_loss: 0.5370 - val_accuracy: 0.7944 - 45ms/epoch - 893us/step
# Epoch 149/300
# 50/50 - 0s - loss: 0.4073 - accuracy: 0.8487 - val_loss: 0.5225 - val_accuracy: 0.7975 - 48ms/epoch - 956us/step
# Epoch 150/300
# 50/50 - 0s - loss: 0.4102 - accuracy: 0.8434 - val_loss: 0.5623 - val_accuracy: 0.7887 - 50ms/epoch - 998us/step
# Epoch 151/300
# 50/50 - 0s - loss: 0.4009 - accuracy: 0.8508 - val_loss: 0.5481 - val_accuracy: 0.8056 - 46ms/epoch - 921us/step
# Epoch 152/300
# 50/50 - 0s - loss: 0.4048 - accuracy: 0.8456 - val_loss: 0.5362 - val_accuracy: 0.7950 - 44ms/epoch - 880us/step
# Epoch 153/300
# 50/50 - 0s - loss: 0.3978 - accuracy: 0.8530 - val_loss: 0.5290 - val_accuracy: 0.7975 - 46ms/epoch - 911us/step
# Epoch 154/300
# 50/50 - 0s - loss: 0.4035 - accuracy: 0.8500 - val_loss: 0.5336 - val_accuracy: 0.7931 - 45ms/epoch - 902us/step
# Epoch 155/300
# 50/50 - 0s - loss: 0.4109 - accuracy: 0.8439 - val_loss: 0.5526 - val_accuracy: 0.8025 - 45ms/epoch - 895us/step
# Epoch 156/300
# 50/50 - 0s - loss: 0.4020 - accuracy: 0.8455 - val_loss: 0.5306 - val_accuracy: 0.8012 - 45ms/epoch - 907us/step
# Epoch 157/300
# 50/50 - 0s - loss: 0.3929 - accuracy: 0.8508 - val_loss: 0.5400 - val_accuracy: 0.7987 - 44ms/epoch - 877us/step
# Epoch 158/300
# 50/50 - 0s - loss: 0.4027 - accuracy: 0.8473 - val_loss: 0.5362 - val_accuracy: 0.8019 - 42ms/epoch - 836us/step
# Epoch 159/300
# 50/50 - 0s - loss: 0.3987 - accuracy: 0.8475 - val_loss: 0.5411 - val_accuracy: 0.8000 - 46ms/epoch - 918us/step
# Epoch 160/300
# 50/50 - 0s - loss: 0.3961 - accuracy: 0.8475 - val_loss: 0.5309 - val_accuracy: 0.8006 - 47ms/epoch - 946us/step
# Epoch 161/300
# 50/50 - 0s - loss: 0.3932 - accuracy: 0.8531 - val_loss: 0.5560 - val_accuracy: 0.7919 - 46ms/epoch - 924us/step
# Epoch 162/300
# 50/50 - 0s - loss: 0.4015 - accuracy: 0.8500 - val_loss: 0.5526 - val_accuracy: 0.7994 - 45ms/epoch - 893us/step
# Epoch 163/300
# 50/50 - 0s - loss: 0.3893 - accuracy: 0.8512 - val_loss: 0.5591 - val_accuracy: 0.8012 - 46ms/epoch - 914us/step
# Epoch 164/300
# 50/50 - 0s - loss: 0.3988 - accuracy: 0.8494 - val_loss: 0.5479 - val_accuracy: 0.8019 - 45ms/epoch - 895us/step
# Epoch 165/300
# 50/50 - 0s - loss: 0.4021 - accuracy: 0.8506 - val_loss: 0.5287 - val_accuracy: 0.7975 - 45ms/epoch - 902us/step
# Epoch 166/300
# 50/50 - 0s - loss: 0.4121 - accuracy: 0.8447 - val_loss: 0.5422 - val_accuracy: 0.7994 - 45ms/epoch - 894us/step
# Epoch 167/300
# 50/50 - 0s - loss: 0.3887 - accuracy: 0.8502 - val_loss: 0.5610 - val_accuracy: 0.7987 - 43ms/epoch - 859us/step
# Epoch 168/300
# 50/50 - 0s - loss: 0.4096 - accuracy: 0.8405 - val_loss: 0.5586 - val_accuracy: 0.7994 - 47ms/epoch - 934us/step
# Epoch 169/300
# 50/50 - 0s - loss: 0.3949 - accuracy: 0.8517 - val_loss: 0.5536 - val_accuracy: 0.7944 - 46ms/epoch - 919us/step
# Epoch 170/300
# 50/50 - 0s - loss: 0.3781 - accuracy: 0.8527 - val_loss: 0.5655 - val_accuracy: 0.7994 - 45ms/epoch - 891us/step
# Epoch 171/300
# 50/50 - 0s - loss: 0.3958 - accuracy: 0.8514 - val_loss: 0.5514 - val_accuracy: 0.8000 - 45ms/epoch - 899us/step
# Epoch 172/300
# 50/50 - 0s - loss: 0.3897 - accuracy: 0.8472 - val_loss: 0.5424 - val_accuracy: 0.7994 - 45ms/epoch - 893us/step
# Epoch 173/300
# 50/50 - 0s - loss: 0.4037 - accuracy: 0.8517 - val_loss: 0.5508 - val_accuracy: 0.7987 - 44ms/epoch - 878us/step
# Epoch 174/300
# 50/50 - 0s - loss: 0.3966 - accuracy: 0.8445 - val_loss: 0.5106 - val_accuracy: 0.8025 - 44ms/epoch - 875us/step
# Epoch 175/300
# 50/50 - 0s - loss: 0.3860 - accuracy: 0.8578 - val_loss: 0.5247 - val_accuracy: 0.7994 - 44ms/epoch - 886us/step
# Epoch 176/300
# 50/50 - 0s - loss: 0.3822 - accuracy: 0.8533 - val_loss: 0.5273 - val_accuracy: 0.7944 - 44ms/epoch - 877us/step
# Epoch 177/300
# 50/50 - 0s - loss: 0.3853 - accuracy: 0.8556 - val_loss: 0.5319 - val_accuracy: 0.8006 - 45ms/epoch - 895us/step
# Epoch 178/300
# 50/50 - 0s - loss: 0.3922 - accuracy: 0.8508 - val_loss: 0.5177 - val_accuracy: 0.8019 - 46ms/epoch - 912us/step
# Epoch 179/300
# 50/50 - 0s - loss: 0.3865 - accuracy: 0.8562 - val_loss: 0.5472 - val_accuracy: 0.8037 - 46ms/epoch - 911us/step
# Epoch 180/300
# 50/50 - 0s - loss: 0.3959 - accuracy: 0.8487 - val_loss: 0.5430 - val_accuracy: 0.8000 - 44ms/epoch - 884us/step
# Epoch 181/300
# 50/50 - 0s - loss: 0.3795 - accuracy: 0.8509 - val_loss: 0.5478 - val_accuracy: 0.8094 - 44ms/epoch - 881us/step
# Epoch 182/300
# 50/50 - 0s - loss: 0.3932 - accuracy: 0.8544 - val_loss: 0.5126 - val_accuracy: 0.7994 - 45ms/epoch - 907us/step
# Epoch 183/300
# 50/50 - 0s - loss: 0.3956 - accuracy: 0.8502 - val_loss: 0.5414 - val_accuracy: 0.8000 - 45ms/epoch - 900us/step
# Epoch 184/300
# 50/50 - 0s - loss: 0.3996 - accuracy: 0.8508 - val_loss: 0.5442 - val_accuracy: 0.7994 - 45ms/epoch - 908us/step
# Epoch 185/300
# 50/50 - 0s - loss: 0.3948 - accuracy: 0.8552 - val_loss: 0.5264 - val_accuracy: 0.8044 - 43ms/epoch - 854us/step
# Epoch 186/300
# 50/50 - 0s - loss: 0.3811 - accuracy: 0.8542 - val_loss: 0.5435 - val_accuracy: 0.7994 - 42ms/epoch - 836us/step
# Epoch 187/300
# 50/50 - 0s - loss: 0.3839 - accuracy: 0.8589 - val_loss: 0.5333 - val_accuracy: 0.8037 - 47ms/epoch - 947us/step
# Epoch 188/300
# 50/50 - 0s - loss: 0.3928 - accuracy: 0.8492 - val_loss: 0.5316 - val_accuracy: 0.7962 - 47ms/epoch - 944us/step
# Epoch 189/300
# 50/50 - 0s - loss: 0.3704 - accuracy: 0.8627 - val_loss: 0.5564 - val_accuracy: 0.8056 - 46ms/epoch - 917us/step
# Epoch 190/300
# 50/50 - 0s - loss: 0.3818 - accuracy: 0.8522 - val_loss: 0.5214 - val_accuracy: 0.8069 - 46ms/epoch - 925us/step
# Epoch 191/300
# 50/50 - 0s - loss: 0.3999 - accuracy: 0.8509 - val_loss: 0.5489 - val_accuracy: 0.8044 - 43ms/epoch - 864us/step
# Epoch 192/300
# 50/50 - 0s - loss: 0.3883 - accuracy: 0.8544 - val_loss: 0.5724 - val_accuracy: 0.7937 - 41ms/epoch - 830us/step
# Epoch 193/300
# 50/50 - 0s - loss: 0.3826 - accuracy: 0.8520 - val_loss: 0.5479 - val_accuracy: 0.8062 - 44ms/epoch - 888us/step
# Epoch 194/300
# 50/50 - 0s - loss: 0.3715 - accuracy: 0.8606 - val_loss: 0.5635 - val_accuracy: 0.8069 - 42ms/epoch - 846us/step
# Epoch 195/300
# 50/50 - 0s - loss: 0.3939 - accuracy: 0.8595 - val_loss: 0.5457 - val_accuracy: 0.7987 - 41ms/epoch - 820us/step
# Epoch 196/300
# 50/50 - 0s - loss: 0.3807 - accuracy: 0.8567 - val_loss: 0.5511 - val_accuracy: 0.8000 - 40ms/epoch - 798us/step
# Epoch 197/300
# 50/50 - 0s - loss: 0.3818 - accuracy: 0.8545 - val_loss: 0.5453 - val_accuracy: 0.8012 - 40ms/epoch - 791us/step
# Epoch 198/300
# 50/50 - 0s - loss: 0.3891 - accuracy: 0.8555 - val_loss: 0.5649 - val_accuracy: 0.7925 - 41ms/epoch - 814us/step
# Epoch 199/300
# 50/50 - 0s - loss: 0.3802 - accuracy: 0.8575 - val_loss: 0.5548 - val_accuracy: 0.8069 - 39ms/epoch - 787us/step
# Epoch 200/300
# 50/50 - 0s - loss: 0.3812 - accuracy: 0.8606 - val_loss: 0.5342 - val_accuracy: 0.8037 - 39ms/epoch - 786us/step
# Epoch 201/300
# 50/50 - 0s - loss: 0.3870 - accuracy: 0.8580 - val_loss: 0.5182 - val_accuracy: 0.8044 - 40ms/epoch - 800us/step
# Epoch 202/300
# 50/50 - 0s - loss: 0.3872 - accuracy: 0.8537 - val_loss: 0.5349 - val_accuracy: 0.8019 - 42ms/epoch - 840us/step
# Epoch 203/300
# 50/50 - 0s - loss: 0.3763 - accuracy: 0.8605 - val_loss: 0.5330 - val_accuracy: 0.8006 - 42ms/epoch - 835us/step
# Epoch 204/300
# 50/50 - 0s - loss: 0.3888 - accuracy: 0.8584 - val_loss: 0.5475 - val_accuracy: 0.7969 - 45ms/epoch - 896us/step
# Epoch 205/300
# 50/50 - 0s - loss: 0.3794 - accuracy: 0.8595 - val_loss: 0.5251 - val_accuracy: 0.7975 - 46ms/epoch - 914us/step
# Epoch 206/300
# 50/50 - 0s - loss: 0.3763 - accuracy: 0.8575 - val_loss: 0.5104 - val_accuracy: 0.8087 - 43ms/epoch - 854us/step
# Epoch 207/300
# 50/50 - 0s - loss: 0.3774 - accuracy: 0.8567 - val_loss: 0.5178 - val_accuracy: 0.8119 - 42ms/epoch - 833us/step
# Epoch 208/300
# 50/50 - 0s - loss: 0.3928 - accuracy: 0.8570 - val_loss: 0.5196 - val_accuracy: 0.8037 - 40ms/epoch - 805us/step
# Epoch 209/300
# 50/50 - 0s - loss: 0.3792 - accuracy: 0.8583 - val_loss: 0.5566 - val_accuracy: 0.8106 - 45ms/epoch - 899us/step
# Epoch 210/300
# 50/50 - 0s - loss: 0.3649 - accuracy: 0.8633 - val_loss: 0.5383 - val_accuracy: 0.8106 - 45ms/epoch - 896us/step
# Epoch 211/300
# 50/50 - 0s - loss: 0.3736 - accuracy: 0.8630 - val_loss: 0.5112 - val_accuracy: 0.8050 - 42ms/epoch - 848us/step
# Epoch 212/300
# 50/50 - 0s - loss: 0.3706 - accuracy: 0.8645 - val_loss: 0.5300 - val_accuracy: 0.7944 - 44ms/epoch - 885us/step
# Epoch 213/300
# 50/50 - 0s - loss: 0.3748 - accuracy: 0.8645 - val_loss: 0.5055 - val_accuracy: 0.8081 - 45ms/epoch - 908us/step
# Epoch 214/300
# 50/50 - 0s - loss: 0.3710 - accuracy: 0.8614 - val_loss: 0.5012 - val_accuracy: 0.8144 - 42ms/epoch - 838us/step
# Epoch 215/300
# 50/50 - 0s - loss: 0.3734 - accuracy: 0.8612 - val_loss: 0.5010 - val_accuracy: 0.8106 - 42ms/epoch - 835us/step
# Epoch 216/300
# 50/50 - 0s - loss: 0.3813 - accuracy: 0.8591 - val_loss: 0.5103 - val_accuracy: 0.8012 - 40ms/epoch - 809us/step
# Epoch 217/300
# 50/50 - 0s - loss: 0.3637 - accuracy: 0.8647 - val_loss: 0.5215 - val_accuracy: 0.8069 - 40ms/epoch - 804us/step
# Epoch 218/300
# 50/50 - 0s - loss: 0.3810 - accuracy: 0.8605 - val_loss: 0.5098 - val_accuracy: 0.7981 - 40ms/epoch - 808us/step
# Epoch 219/300
# 50/50 - 0s - loss: 0.3846 - accuracy: 0.8534 - val_loss: 0.5211 - val_accuracy: 0.8025 - 40ms/epoch - 797us/step
# Epoch 220/300
# 50/50 - 0s - loss: 0.3820 - accuracy: 0.8528 - val_loss: 0.5212 - val_accuracy: 0.8094 - 41ms/epoch - 828us/step
# Epoch 221/300
# 50/50 - 0s - loss: 0.3720 - accuracy: 0.8575 - val_loss: 0.5297 - val_accuracy: 0.8050 - 42ms/epoch - 832us/step
# Epoch 222/300
# 50/50 - 0s - loss: 0.3801 - accuracy: 0.8591 - val_loss: 0.5140 - val_accuracy: 0.8044 - 43ms/epoch - 865us/step
# Epoch 223/300
# 50/50 - 0s - loss: 0.3673 - accuracy: 0.8684 - val_loss: 0.5280 - val_accuracy: 0.8037 - 42ms/epoch - 833us/step
# Epoch 224/300
# 50/50 - 0s - loss: 0.3577 - accuracy: 0.8706 - val_loss: 0.5221 - val_accuracy: 0.8106 - 40ms/epoch - 796us/step
# Epoch 225/300
# 50/50 - 0s - loss: 0.3559 - accuracy: 0.8658 - val_loss: 0.5293 - val_accuracy: 0.8069 - 40ms/epoch - 809us/step
# Epoch 226/300
# 50/50 - 0s - loss: 0.3634 - accuracy: 0.8652 - val_loss: 0.5422 - val_accuracy: 0.8037 - 41ms/epoch - 811us/step
# Epoch 227/300
# 50/50 - 0s - loss: 0.3780 - accuracy: 0.8608 - val_loss: 0.5489 - val_accuracy: 0.8094 - 40ms/epoch - 809us/step
# Epoch 228/300
# 50/50 - 0s - loss: 0.3908 - accuracy: 0.8564 - val_loss: 0.5194 - val_accuracy: 0.8044 - 42ms/epoch - 848us/step
# Epoch 229/300
# 50/50 - 0s - loss: 0.3599 - accuracy: 0.8608 - val_loss: 0.5285 - val_accuracy: 0.8081 - 43ms/epoch - 857us/step
# Epoch 230/300
# 50/50 - 0s - loss: 0.3744 - accuracy: 0.8655 - val_loss: 0.5244 - val_accuracy: 0.8087 - 40ms/epoch - 802us/step
# Epoch 231/300
# 50/50 - 0s - loss: 0.3693 - accuracy: 0.8627 - val_loss: 0.5150 - val_accuracy: 0.8138 - 39ms/epoch - 783us/step
# Epoch 232/300
# 50/50 - 0s - loss: 0.3583 - accuracy: 0.8666 - val_loss: 0.5200 - val_accuracy: 0.8125 - 40ms/epoch - 793us/step
# Epoch 233/300
# 50/50 - 0s - loss: 0.3641 - accuracy: 0.8608 - val_loss: 0.5731 - val_accuracy: 0.8025 - 39ms/epoch - 786us/step
# Epoch 234/300
# 50/50 - 0s - loss: 0.3605 - accuracy: 0.8653 - val_loss: 0.5193 - val_accuracy: 0.8062 - 39ms/epoch - 788us/step
# Epoch 235/300
# 50/50 - 0s - loss: 0.3799 - accuracy: 0.8648 - val_loss: 0.5312 - val_accuracy: 0.8075 - 39ms/epoch - 785us/step
# Epoch 236/300
# 50/50 - 0s - loss: 0.3583 - accuracy: 0.8617 - val_loss: 0.5737 - val_accuracy: 0.7987 - 40ms/epoch - 805us/step
# Epoch 237/300
# 50/50 - 0s - loss: 0.3550 - accuracy: 0.8652 - val_loss: 0.5333 - val_accuracy: 0.8075 - 41ms/epoch - 813us/step
# Epoch 238/300
# 50/50 - 0s - loss: 0.3631 - accuracy: 0.8653 - val_loss: 0.5628 - val_accuracy: 0.8062 - 42ms/epoch - 831us/step
# Epoch 239/300
# 50/50 - 0s - loss: 0.3663 - accuracy: 0.8627 - val_loss: 0.5459 - val_accuracy: 0.8125 - 40ms/epoch - 803us/step
# Epoch 240/300
# 50/50 - 0s - loss: 0.3664 - accuracy: 0.8642 - val_loss: 0.5424 - val_accuracy: 0.8100 - 40ms/epoch - 794us/step
# Epoch 241/300
# 50/50 - 0s - loss: 0.3625 - accuracy: 0.8644 - val_loss: 0.5754 - val_accuracy: 0.7987 - 40ms/epoch - 808us/step
# Epoch 242/300
# 50/50 - 0s - loss: 0.3671 - accuracy: 0.8645 - val_loss: 0.5313 - val_accuracy: 0.8094 - 40ms/epoch - 791us/step
# Epoch 243/300
# 50/50 - 0s - loss: 0.3630 - accuracy: 0.8650 - val_loss: 0.5124 - val_accuracy: 0.8106 - 39ms/epoch - 784us/step
# Epoch 244/300
# 50/50 - 0s - loss: 0.3805 - accuracy: 0.8642 - val_loss: 0.5381 - val_accuracy: 0.8125 - 39ms/epoch - 784us/step
# Epoch 245/300
# 50/50 - 0s - loss: 0.3553 - accuracy: 0.8681 - val_loss: 0.5303 - val_accuracy: 0.8037 - 41ms/epoch - 817us/step
# Epoch 246/300
# 50/50 - 0s - loss: 0.3645 - accuracy: 0.8636 - val_loss: 0.5278 - val_accuracy: 0.8119 - 41ms/epoch - 825us/step
# Epoch 247/300
# 50/50 - 0s - loss: 0.3806 - accuracy: 0.8625 - val_loss: 0.5173 - val_accuracy: 0.8094 - 41ms/epoch - 825us/step
# Epoch 248/300
# 50/50 - 0s - loss: 0.3625 - accuracy: 0.8595 - val_loss: 0.5191 - val_accuracy: 0.8150 - 41ms/epoch - 815us/step
# Epoch 249/300
# 50/50 - 0s - loss: 0.3670 - accuracy: 0.8667 - val_loss: 0.5294 - val_accuracy: 0.8087 - 40ms/epoch - 795us/step
# Epoch 250/300
# 50/50 - 0s - loss: 0.3530 - accuracy: 0.8672 - val_loss: 0.5252 - val_accuracy: 0.8056 - 40ms/epoch - 804us/step
# Epoch 251/300
# 50/50 - 0s - loss: 0.3624 - accuracy: 0.8670 - val_loss: 0.5363 - val_accuracy: 0.8087 - 40ms/epoch - 800us/step
# Epoch 252/300
# 50/50 - 0s - loss: 0.3707 - accuracy: 0.8636 - val_loss: 0.5225 - val_accuracy: 0.8131 - 39ms/epoch - 782us/step
# Epoch 253/300
# 50/50 - 0s - loss: 0.3695 - accuracy: 0.8612 - val_loss: 0.5283 - val_accuracy: 0.8144 - 39ms/epoch - 788us/step
# Epoch 254/300
# 50/50 - 0s - loss: 0.3590 - accuracy: 0.8669 - val_loss: 0.5195 - val_accuracy: 0.8219 - 41ms/epoch - 815us/step
# Epoch 255/300
# 50/50 - 0s - loss: 0.3548 - accuracy: 0.8694 - val_loss: 0.5344 - val_accuracy: 0.8144 - 38ms/epoch - 768us/step
# Epoch 256/300
# 50/50 - 0s - loss: 0.3569 - accuracy: 0.8745 - val_loss: 0.5324 - val_accuracy: 0.8144 - 41ms/epoch - 813us/step
# Epoch 257/300
# 50/50 - 0s - loss: 0.3590 - accuracy: 0.8667 - val_loss: 0.5383 - val_accuracy: 0.8181 - 40ms/epoch - 798us/step
# Epoch 258/300
# 50/50 - 0s - loss: 0.3560 - accuracy: 0.8702 - val_loss: 0.5263 - val_accuracy: 0.8131 - 39ms/epoch - 772us/step
# Epoch 259/300
# 50/50 - 0s - loss: 0.3553 - accuracy: 0.8661 - val_loss: 0.5635 - val_accuracy: 0.8075 - 40ms/epoch - 809us/step
# Epoch 260/300
# 50/50 - 0s - loss: 0.3682 - accuracy: 0.8612 - val_loss: 0.5534 - val_accuracy: 0.8131 - 40ms/epoch - 790us/step
# Epoch 261/300
# 50/50 - 0s - loss: 0.3497 - accuracy: 0.8664 - val_loss: 0.5364 - val_accuracy: 0.8163 - 42ms/epoch - 838us/step
# Epoch 262/300
# 50/50 - 0s - loss: 0.3532 - accuracy: 0.8681 - val_loss: 0.5632 - val_accuracy: 0.8100 - 41ms/epoch - 822us/step
# Epoch 263/300
# 50/50 - 0s - loss: 0.3563 - accuracy: 0.8702 - val_loss: 0.5285 - val_accuracy: 0.8125 - 39ms/epoch - 789us/step
# Epoch 264/300
# 50/50 - 0s - loss: 0.3690 - accuracy: 0.8658 - val_loss: 0.5033 - val_accuracy: 0.8181 - 40ms/epoch - 795us/step
# Epoch 265/300
# 50/50 - 0s - loss: 0.3572 - accuracy: 0.8652 - val_loss: 0.5272 - val_accuracy: 0.8094 - 41ms/epoch - 827us/step
# Epoch 266/300
# 50/50 - 0s - loss: 0.3543 - accuracy: 0.8703 - val_loss: 0.5337 - val_accuracy: 0.8144 - 39ms/epoch - 781us/step
# Epoch 267/300
# 50/50 - 0s - loss: 0.3534 - accuracy: 0.8681 - val_loss: 0.5545 - val_accuracy: 0.8069 - 40ms/epoch - 795us/step
# Epoch 268/300
# 50/50 - 0s - loss: 0.3510 - accuracy: 0.8723 - val_loss: 0.5495 - val_accuracy: 0.8150 - 40ms/epoch - 797us/step
# Epoch 269/300
# 50/50 - 0s - loss: 0.3548 - accuracy: 0.8642 - val_loss: 0.5467 - val_accuracy: 0.8112 - 40ms/epoch - 793us/step
# Epoch 270/300
# 50/50 - 0s - loss: 0.3727 - accuracy: 0.8683 - val_loss: 0.5271 - val_accuracy: 0.8000 - 39ms/epoch - 790us/step
# Epoch 271/300
# 50/50 - 0s - loss: 0.3599 - accuracy: 0.8659 - val_loss: 0.5408 - val_accuracy: 0.8069 - 41ms/epoch - 823us/step
# Epoch 272/300
# 50/50 - 0s - loss: 0.3582 - accuracy: 0.8666 - val_loss: 0.5105 - val_accuracy: 0.8112 - 41ms/epoch - 820us/step
# Epoch 273/300
# 50/50 - 0s - loss: 0.3733 - accuracy: 0.8680 - val_loss: 0.5346 - val_accuracy: 0.8031 - 175ms/epoch - 4ms/step
# Epoch 274/300
# 50/50 - 0s - loss: 0.3519 - accuracy: 0.8697 - val_loss: 0.5317 - val_accuracy: 0.8087 - 59ms/epoch - 1ms/step
# Epoch 275/300
# 50/50 - 0s - loss: 0.3537 - accuracy: 0.8662 - val_loss: 0.5485 - val_accuracy: 0.7987 - 43ms/epoch - 861us/step
# Epoch 276/300
# 50/50 - 0s - loss: 0.3407 - accuracy: 0.8700 - val_loss: 0.5446 - val_accuracy: 0.8031 - 39ms/epoch - 775us/step
# Epoch 277/300
# 50/50 - 0s - loss: 0.3514 - accuracy: 0.8694 - val_loss: 0.5511 - val_accuracy: 0.8094 - 38ms/epoch - 766us/step
# Epoch 278/300
# 50/50 - 0s - loss: 0.3538 - accuracy: 0.8650 - val_loss: 0.5596 - val_accuracy: 0.8131 - 40ms/epoch - 793us/step
# Epoch 279/300
# 50/50 - 0s - loss: 0.3481 - accuracy: 0.8737 - val_loss: 0.5653 - val_accuracy: 0.8050 - 40ms/epoch - 802us/step
# Epoch 280/300
# 50/50 - 0s - loss: 0.3644 - accuracy: 0.8681 - val_loss: 0.5217 - val_accuracy: 0.8138 - 39ms/epoch - 787us/step
# Epoch 281/300
# 50/50 - 0s - loss: 0.3668 - accuracy: 0.8620 - val_loss: 0.5660 - val_accuracy: 0.8169 - 38ms/epoch - 763us/step
# Epoch 282/300
# 50/50 - 0s - loss: 0.3529 - accuracy: 0.8680 - val_loss: 0.5763 - val_accuracy: 0.8175 - 40ms/epoch - 793us/step
# Epoch 283/300
# 50/50 - 0s - loss: 0.3492 - accuracy: 0.8695 - val_loss: 0.5619 - val_accuracy: 0.8169 - 39ms/epoch - 774us/step
# Epoch 284/300
# 50/50 - 0s - loss: 0.3574 - accuracy: 0.8631 - val_loss: 0.5706 - val_accuracy: 0.8138 - 39ms/epoch - 778us/step
# Epoch 285/300
# 50/50 - 0s - loss: 0.3575 - accuracy: 0.8642 - val_loss: 0.5901 - val_accuracy: 0.8087 - 39ms/epoch - 788us/step
# Epoch 286/300
# 50/50 - 0s - loss: 0.3503 - accuracy: 0.8675 - val_loss: 0.5487 - val_accuracy: 0.8106 - 40ms/epoch - 804us/step
# Epoch 287/300
# 50/50 - 0s - loss: 0.3702 - accuracy: 0.8659 - val_loss: 0.5681 - val_accuracy: 0.8062 - 40ms/epoch - 798us/step
# Epoch 288/300
# 50/50 - 0s - loss: 0.3541 - accuracy: 0.8633 - val_loss: 0.5492 - val_accuracy: 0.8144 - 40ms/epoch - 795us/step
# Epoch 289/300
# 50/50 - 0s - loss: 0.3513 - accuracy: 0.8670 - val_loss: 0.5538 - val_accuracy: 0.8150 - 40ms/epoch - 796us/step
# Epoch 290/300
# 50/50 - 0s - loss: 0.3403 - accuracy: 0.8736 - val_loss: 0.5672 - val_accuracy: 0.8144 - 41ms/epoch - 811us/step
# Epoch 291/300
# 50/50 - 0s - loss: 0.3366 - accuracy: 0.8816 - val_loss: 0.5592 - val_accuracy: 0.8131 - 43ms/epoch - 853us/step
# Epoch 292/300
# 50/50 - 0s - loss: 0.3462 - accuracy: 0.8716 - val_loss: 0.5597 - val_accuracy: 0.8125 - 40ms/epoch - 794us/step
# Epoch 293/300
# 50/50 - 0s - loss: 0.3520 - accuracy: 0.8691 - val_loss: 0.5272 - val_accuracy: 0.8075 - 40ms/epoch - 800us/step
# Epoch 294/300
# 50/50 - 0s - loss: 0.3607 - accuracy: 0.8722 - val_loss: 0.5332 - val_accuracy: 0.8181 - 41ms/epoch - 830us/step
# Epoch 295/300
# 50/50 - 0s - loss: 0.3473 - accuracy: 0.8750 - val_loss: 0.5484 - val_accuracy: 0.8150 - 40ms/epoch - 809us/step
# Epoch 296/300
# 50/50 - 0s - loss: 0.3416 - accuracy: 0.8720 - val_loss: 0.5511 - val_accuracy: 0.8094 - 41ms/epoch - 824us/step
# Epoch 297/300
# 50/50 - 0s - loss: 0.3534 - accuracy: 0.8697 - val_loss: 0.5440 - val_accuracy: 0.8194 - 41ms/epoch - 823us/step
# Epoch 298/300
# 50/50 - 0s - loss: 0.3597 - accuracy: 0.8689 - val_loss: 0.5418 - val_accuracy: 0.8087 - 41ms/epoch - 813us/step
# Epoch 299/300
# 50/50 - 0s - loss: 0.3578 - accuracy: 0.8662 - val_loss: 0.5279 - val_accuracy: 0.8150 - 38ms/epoch - 751us/step
# Epoch 300/300
# 50/50 - 0s - loss: 0.3561 - accuracy: 0.8670 - val_loss: 0.5169 - val_accuracy: 0.8144 - 39ms/epoch - 780us/step
# Index(['loan_amnt', 'term', 'emp_length', 'home_ownership', 'annual_inc',
#        'purpose', 'dti', 'delinq_2yrs', 'cr_hist_age_mths', 'fico_range_low',
#        'fico_range_high', 'inq_last_6mths', 'inv_mths_since_last_delinq',
#        'inv_mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'collections_12_mths_ex_med',
#        'inv_mths_since_last_major_derog', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'total_rev_hi_lim', 'acc_open_past_24mths',
#        'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op',
#        'inv_mo_sin_rcnt_rev_tl_op', 'inv_mo_sin_rcnt_tl', 'mort_acc',
#        'inv_mths_since_recent_bc', 'inv_mths_since_recent_bc_dlq',
#        'inv_mths_since_recent_inq', 'inv_mths_since_recent_revol_delinq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m',
#        'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',
#        'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies',
#        'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object')
# Epoch 1/300
# 50/50 - 0s - loss: 1.7460 - accuracy: 0.3022 - val_loss: 1.4665 - val_accuracy: 0.4487 - 203ms/epoch - 4ms/step
# Epoch 2/300
# 50/50 - 0s - loss: 1.5238 - accuracy: 0.3805 - val_loss: 1.3300 - val_accuracy: 0.4950 - 36ms/epoch - 726us/step
# Epoch 3/300
# 50/50 - 0s - loss: 1.4270 - accuracy: 0.4191 - val_loss: 1.2499 - val_accuracy: 0.5219 - 39ms/epoch - 779us/step
# Epoch 4/300
# 50/50 - 0s - loss: 1.3565 - accuracy: 0.4461 - val_loss: 1.1749 - val_accuracy: 0.5469 - 39ms/epoch - 775us/step
# Epoch 5/300
# 50/50 - 0s - loss: 1.2787 - accuracy: 0.4641 - val_loss: 1.1016 - val_accuracy: 0.5544 - 41ms/epoch - 825us/step
# Epoch 6/300
# 50/50 - 0s - loss: 1.2052 - accuracy: 0.5048 - val_loss: 1.0204 - val_accuracy: 0.5725 - 39ms/epoch - 775us/step
# Epoch 7/300
# 50/50 - 0s - loss: 1.1289 - accuracy: 0.5286 - val_loss: 0.9495 - val_accuracy: 0.6006 - 39ms/epoch - 774us/step
# Epoch 8/300
# 50/50 - 0s - loss: 1.0975 - accuracy: 0.5422 - val_loss: 0.9009 - val_accuracy: 0.6413 - 39ms/epoch - 772us/step
# Epoch 9/300
# 50/50 - 0s - loss: 1.0423 - accuracy: 0.5617 - val_loss: 0.8433 - val_accuracy: 0.6869 - 38ms/epoch - 761us/step
# Epoch 10/300
# 50/50 - 0s - loss: 0.9982 - accuracy: 0.5927 - val_loss: 0.8093 - val_accuracy: 0.7006 - 154ms/epoch - 3ms/step
# Epoch 11/300
# 50/50 - 0s - loss: 0.9427 - accuracy: 0.6047 - val_loss: 0.7630 - val_accuracy: 0.7138 - 60ms/epoch - 1ms/step
# Epoch 12/300
# 50/50 - 0s - loss: 0.9217 - accuracy: 0.6130 - val_loss: 0.7457 - val_accuracy: 0.7113 - 67ms/epoch - 1ms/step
# Epoch 13/300
# 50/50 - 0s - loss: 0.8979 - accuracy: 0.6347 - val_loss: 0.7272 - val_accuracy: 0.7225 - 39ms/epoch - 789us/step
# Epoch 14/300
# 50/50 - 0s - loss: 0.8744 - accuracy: 0.6378 - val_loss: 0.7045 - val_accuracy: 0.7275 - 40ms/epoch - 802us/step
# Epoch 15/300
# 50/50 - 0s - loss: 0.8605 - accuracy: 0.6423 - val_loss: 0.6895 - val_accuracy: 0.7356 - 39ms/epoch - 786us/step
# Epoch 16/300
# 50/50 - 0s - loss: 0.8345 - accuracy: 0.6553 - val_loss: 0.6694 - val_accuracy: 0.7525 - 40ms/epoch - 792us/step
# Epoch 17/300
# 50/50 - 0s - loss: 0.8195 - accuracy: 0.6622 - val_loss: 0.6685 - val_accuracy: 0.7456 - 38ms/epoch - 764us/step
# Epoch 18/300
# 50/50 - 0s - loss: 0.8156 - accuracy: 0.6598 - val_loss: 0.6564 - val_accuracy: 0.7462 - 38ms/epoch - 768us/step
# Epoch 19/300
# 50/50 - 0s - loss: 0.8011 - accuracy: 0.6641 - val_loss: 0.6409 - val_accuracy: 0.7556 - 38ms/epoch - 766us/step
# Epoch 20/300
# 50/50 - 0s - loss: 0.7866 - accuracy: 0.6747 - val_loss: 0.6396 - val_accuracy: 0.7544 - 38ms/epoch - 757us/step
# Epoch 21/300
# 50/50 - 0s - loss: 0.7680 - accuracy: 0.6873 - val_loss: 0.6270 - val_accuracy: 0.7613 - 39ms/epoch - 788us/step
# Epoch 22/300
# 50/50 - 0s - loss: 0.7489 - accuracy: 0.6917 - val_loss: 0.6081 - val_accuracy: 0.7656 - 39ms/epoch - 775us/step
# Epoch 23/300
# 50/50 - 0s - loss: 0.7464 - accuracy: 0.6966 - val_loss: 0.6165 - val_accuracy: 0.7556 - 38ms/epoch - 762us/step
# Epoch 24/300
# 50/50 - 0s - loss: 0.7340 - accuracy: 0.6875 - val_loss: 0.6018 - val_accuracy: 0.7725 - 38ms/epoch - 754us/step
# Epoch 25/300
# 50/50 - 0s - loss: 0.7267 - accuracy: 0.6900 - val_loss: 0.5952 - val_accuracy: 0.7631 - 39ms/epoch - 784us/step
# Epoch 26/300
# 50/50 - 0s - loss: 0.7213 - accuracy: 0.7033 - val_loss: 0.5969 - val_accuracy: 0.7619 - 42ms/epoch - 831us/step
# Epoch 27/300
# 50/50 - 0s - loss: 0.7050 - accuracy: 0.7119 - val_loss: 0.5796 - val_accuracy: 0.7744 - 39ms/epoch - 781us/step
# Epoch 28/300
# 50/50 - 0s - loss: 0.7099 - accuracy: 0.7108 - val_loss: 0.5839 - val_accuracy: 0.7731 - 38ms/epoch - 756us/step
# Epoch 29/300
# 50/50 - 0s - loss: 0.7001 - accuracy: 0.7188 - val_loss: 0.5655 - val_accuracy: 0.7844 - 39ms/epoch - 782us/step
# Epoch 30/300
# 50/50 - 0s - loss: 0.6896 - accuracy: 0.7139 - val_loss: 0.5664 - val_accuracy: 0.7725 - 40ms/epoch - 794us/step
# Epoch 31/300
# 50/50 - 0s - loss: 0.6853 - accuracy: 0.7172 - val_loss: 0.5594 - val_accuracy: 0.7825 - 39ms/epoch - 777us/step
# Epoch 32/300
# 50/50 - 0s - loss: 0.6623 - accuracy: 0.7272 - val_loss: 0.5534 - val_accuracy: 0.7756 - 38ms/epoch - 770us/step
# Epoch 33/300
# 50/50 - 0s - loss: 0.6730 - accuracy: 0.7261 - val_loss: 0.5568 - val_accuracy: 0.7731 - 40ms/epoch - 793us/step
# Epoch 34/300
# 50/50 - 0s - loss: 0.6587 - accuracy: 0.7269 - val_loss: 0.5524 - val_accuracy: 0.7694 - 39ms/epoch - 782us/step
# Epoch 35/300
# 50/50 - 0s - loss: 0.6579 - accuracy: 0.7328 - val_loss: 0.5434 - val_accuracy: 0.7856 - 41ms/epoch - 815us/step
# Epoch 36/300
# 50/50 - 0s - loss: 0.6558 - accuracy: 0.7252 - val_loss: 0.5423 - val_accuracy: 0.7681 - 40ms/epoch - 805us/step
# Epoch 37/300
# 50/50 - 0s - loss: 0.6533 - accuracy: 0.7309 - val_loss: 0.5387 - val_accuracy: 0.7800 - 39ms/epoch - 786us/step
# Epoch 38/300
# 50/50 - 0s - loss: 0.6378 - accuracy: 0.7391 - val_loss: 0.5360 - val_accuracy: 0.7825 - 39ms/epoch - 777us/step
# Epoch 39/300
# 50/50 - 0s - loss: 0.6389 - accuracy: 0.7342 - val_loss: 0.5235 - val_accuracy: 0.7912 - 40ms/epoch - 806us/step
# Epoch 40/300
# 50/50 - 0s - loss: 0.6299 - accuracy: 0.7411 - val_loss: 0.5222 - val_accuracy: 0.7875 - 40ms/epoch - 794us/step
# Epoch 41/300
# 50/50 - 0s - loss: 0.6287 - accuracy: 0.7475 - val_loss: 0.5281 - val_accuracy: 0.7862 - 39ms/epoch - 789us/step
# Epoch 42/300
# 50/50 - 0s - loss: 0.6245 - accuracy: 0.7480 - val_loss: 0.5340 - val_accuracy: 0.7837 - 39ms/epoch - 786us/step
# Epoch 43/300
# 50/50 - 0s - loss: 0.6054 - accuracy: 0.7506 - val_loss: 0.5289 - val_accuracy: 0.7788 - 39ms/epoch - 784us/step
# Epoch 44/300
# 50/50 - 0s - loss: 0.6193 - accuracy: 0.7458 - val_loss: 0.5239 - val_accuracy: 0.7819 - 39ms/epoch - 785us/step
# Epoch 45/300
# 50/50 - 0s - loss: 0.6125 - accuracy: 0.7519 - val_loss: 0.5254 - val_accuracy: 0.7819 - 39ms/epoch - 788us/step
# Epoch 46/300
# 50/50 - 0s - loss: 0.6007 - accuracy: 0.7542 - val_loss: 0.5141 - val_accuracy: 0.7819 - 39ms/epoch - 783us/step
# Epoch 47/300
# 50/50 - 0s - loss: 0.6053 - accuracy: 0.7556 - val_loss: 0.5120 - val_accuracy: 0.7919 - 39ms/epoch - 783us/step
# Epoch 48/300
# 50/50 - 0s - loss: 0.5951 - accuracy: 0.7530 - val_loss: 0.5080 - val_accuracy: 0.7919 - 39ms/epoch - 780us/step
# Epoch 49/300
# 50/50 - 0s - loss: 0.5974 - accuracy: 0.7581 - val_loss: 0.5094 - val_accuracy: 0.7956 - 39ms/epoch - 788us/step
# Epoch 50/300
# 50/50 - 0s - loss: 0.5920 - accuracy: 0.7570 - val_loss: 0.5036 - val_accuracy: 0.7944 - 39ms/epoch - 774us/step
# Epoch 51/300
# 50/50 - 0s - loss: 0.5783 - accuracy: 0.7650 - val_loss: 0.4985 - val_accuracy: 0.8006 - 40ms/epoch - 801us/step
# Epoch 52/300
# 50/50 - 0s - loss: 0.5780 - accuracy: 0.7642 - val_loss: 0.4926 - val_accuracy: 0.7969 - 40ms/epoch - 805us/step
# Epoch 53/300
# 50/50 - 0s - loss: 0.5688 - accuracy: 0.7678 - val_loss: 0.4976 - val_accuracy: 0.7925 - 39ms/epoch - 787us/step
# Epoch 54/300
# 50/50 - 0s - loss: 0.5825 - accuracy: 0.7695 - val_loss: 0.5041 - val_accuracy: 0.7944 - 39ms/epoch - 790us/step
# Epoch 55/300
# 50/50 - 0s - loss: 0.5623 - accuracy: 0.7736 - val_loss: 0.4900 - val_accuracy: 0.7962 - 39ms/epoch - 779us/step
# Epoch 56/300
# 50/50 - 0s - loss: 0.5480 - accuracy: 0.7750 - val_loss: 0.4878 - val_accuracy: 0.7944 - 39ms/epoch - 773us/step
# Epoch 57/300
# ...
# Epoch 183/300
# 50/50 - 0s - loss: 0.4053 - accuracy: 0.8431 - val_loss: 0.5290 - val_accuracy: 0.8081 - 40ms/epoch - 805us/step
# Epoch 184/300
# 50/50 - 0s - loss: 0.3957 - accuracy: 0.8522 - val_loss: 0.5282 - val_accuracy: 0.8056 - 40ms/epoch - 791us/step
# Epoch 185/300
# 50/50 - 0s - loss: 0.3875 - accuracy: 0.8498 - val_loss: 0.5400 - val_accuracy: 0.8025 - 40ms/epoch - 791us/step
# Epoch 186/300
# 50/50 - 0s - loss: 0.3931 - accuracy: 0.8527 - val_loss: 0.5398 - val_accuracy: 0.8056 - 40ms/epoch - 794us/step
# Epoch 187/300
# 50/50 - 0s - loss: 0.4061 - accuracy: 0.8472 - val_loss: 0.5399 - val_accuracy: 0.8062 - 40ms/epoch - 801us/step
# Epoch 188/300
# 50/50 - 0s - loss: 0.4079 - accuracy: 0.8455 - val_loss: 0.5362 - val_accuracy: 0.8056 - 40ms/epoch - 796us/step
# Epoch 189/300
# 50/50 - 0s - loss: 0.3962 - accuracy: 0.8487 - val_loss: 0.5219 - val_accuracy: 0.8006 - 39ms/epoch - 786us/step
# Epoch 190/300
# 50/50 - 0s - loss: 0.3911 - accuracy: 0.8523 - val_loss: 0.5351 - val_accuracy: 0.8037 - 39ms/epoch - 784us/step
# Epoch 191/300
# 50/50 - 0s - loss: 0.3708 - accuracy: 0.8627 - val_loss: 0.5319 - val_accuracy: 0.8119 - 39ms/epoch - 780us/step
# Epoch 192/300
# 50/50 - 0s - loss: 0.3893 - accuracy: 0.8500 - val_loss: 0.5304 - val_accuracy: 0.8006 - 40ms/epoch - 796us/step
# Epoch 193/300
# 50/50 - 0s - loss: 0.3911 - accuracy: 0.8514 - val_loss: 0.5276 - val_accuracy: 0.7944 - 39ms/epoch - 786us/step
# Epoch 194/300
# 50/50 - 0s - loss: 0.3839 - accuracy: 0.8573 - val_loss: 0.5375 - val_accuracy: 0.8075 - 40ms/epoch - 794us/step
# Epoch 195/300
# 50/50 - 0s - loss: 0.3957 - accuracy: 0.8462 - val_loss: 0.5456 - val_accuracy: 0.8056 - 40ms/epoch - 794us/step
# Epoch 196/300
# 50/50 - 0s - loss: 0.3780 - accuracy: 0.8530 - val_loss: 0.5416 - val_accuracy: 0.8056 - 40ms/epoch - 795us/step
# Epoch 197/300
# 50/50 - 0s - loss: 0.3932 - accuracy: 0.8484 - val_loss: 0.5357 - val_accuracy: 0.8019 - 40ms/epoch - 801us/step
# Epoch 198/300
# 50/50 - 0s - loss: 0.3900 - accuracy: 0.8534 - val_loss: 0.5368 - val_accuracy: 0.8056 - 40ms/epoch - 799us/step
# Epoch 199/300
# 50/50 - 0s - loss: 0.3721 - accuracy: 0.8597 - val_loss: 0.5493 - val_accuracy: 0.8050 - 40ms/epoch - 797us/step
# Epoch 200/300
# 50/50 - 0s - loss: 0.3936 - accuracy: 0.8525 - val_loss: 0.5326 - val_accuracy: 0.7944 - 39ms/epoch - 789us/step
# Epoch 201/300
# 50/50 - 0s - loss: 0.3853 - accuracy: 0.8581 - val_loss: 0.5434 - val_accuracy: 0.7944 - 40ms/epoch - 790us/step
# Epoch 202/300
# 50/50 - 0s - loss: 0.3898 - accuracy: 0.8520 - val_loss: 0.5330 - val_accuracy: 0.7987 - 40ms/epoch - 798us/step
# Epoch 203/300
# 50/50 - 0s - loss: 0.3743 - accuracy: 0.8564 - val_loss: 0.5384 - val_accuracy: 0.8112 - 40ms/epoch - 794us/step
# Epoch 204/300
# 50/50 - 0s - loss: 0.3804 - accuracy: 0.8564 - val_loss: 0.5458 - val_accuracy: 0.8044 - 40ms/epoch - 792us/step
# Epoch 205/300
# 50/50 - 0s - loss: 0.3762 - accuracy: 0.8534 - val_loss: 0.5453 - val_accuracy: 0.7969 - 43ms/epoch - 857us/step
# Epoch 206/300
# 50/50 - 0s - loss: 0.3870 - accuracy: 0.8512 - val_loss: 0.5601 - val_accuracy: 0.8069 - 41ms/epoch - 813us/step
# Epoch 207/300
# 50/50 - 0s - loss: 0.3718 - accuracy: 0.8539 - val_loss: 0.5616 - val_accuracy: 0.7981 - 40ms/epoch - 793us/step
# Epoch 208/300
# 50/50 - 0s - loss: 0.3853 - accuracy: 0.8473 - val_loss: 0.5488 - val_accuracy: 0.7981 - 40ms/epoch - 806us/step
# Epoch 209/300
# 50/50 - 0s - loss: 0.3774 - accuracy: 0.8544 - val_loss: 0.5443 - val_accuracy: 0.8037 - 39ms/epoch - 784us/step
# Epoch 210/300
# 50/50 - 0s - loss: 0.3789 - accuracy: 0.8616 - val_loss: 0.5428 - val_accuracy: 0.8012 - 39ms/epoch - 783us/step
# Epoch 211/300
# 50/50 - 0s - loss: 0.3873 - accuracy: 0.8497 - val_loss: 0.5442 - val_accuracy: 0.7950 - 40ms/epoch - 791us/step
# Epoch 212/300
# 50/50 - 0s - loss: 0.3911 - accuracy: 0.8509 - val_loss: 0.5477 - val_accuracy: 0.7987 - 40ms/epoch - 792us/step
# Epoch 213/300
# 50/50 - 0s - loss: 0.3832 - accuracy: 0.8511 - val_loss: 0.5385 - val_accuracy: 0.8019 - 39ms/epoch - 782us/step
# Epoch 214/300
# 50/50 - 0s - loss: 0.3752 - accuracy: 0.8573 - val_loss: 0.5395 - val_accuracy: 0.7912 - 40ms/epoch - 792us/step
# Epoch 215/300
# 50/50 - 0s - loss: 0.3823 - accuracy: 0.8580 - val_loss: 0.5429 - val_accuracy: 0.8012 - 40ms/epoch - 791us/step
# Epoch 216/300
# 50/50 - 0s - loss: 0.3872 - accuracy: 0.8550 - val_loss: 0.5408 - val_accuracy: 0.8056 - 43ms/epoch - 862us/step
# Epoch 217/300
# 50/50 - 0s - loss: 0.3925 - accuracy: 0.8530 - val_loss: 0.5501 - val_accuracy: 0.8044 - 41ms/epoch - 819us/step
# Epoch 218/300
# 50/50 - 0s - loss: 0.3760 - accuracy: 0.8583 - val_loss: 0.5627 - val_accuracy: 0.7931 - 40ms/epoch - 800us/step
# Epoch 219/300
# 50/50 - 0s - loss: 0.3806 - accuracy: 0.8544 - val_loss: 0.5635 - val_accuracy: 0.8012 - 40ms/epoch - 797us/step
# Epoch 220/300
# 50/50 - 0s - loss: 0.3901 - accuracy: 0.8527 - val_loss: 0.5568 - val_accuracy: 0.8056 - 40ms/epoch - 794us/step
# Epoch 221/300
# 50/50 - 0s - loss: 0.3725 - accuracy: 0.8583 - val_loss: 0.5493 - val_accuracy: 0.8006 - 40ms/epoch - 792us/step
# Epoch 222/300
# 50/50 - 0s - loss: 0.3775 - accuracy: 0.8569 - val_loss: 0.5504 - val_accuracy: 0.8006 - 39ms/epoch - 787us/step
# Epoch 223/300
# 50/50 - 0s - loss: 0.3748 - accuracy: 0.8539 - val_loss: 0.5418 - val_accuracy: 0.8087 - 40ms/epoch - 806us/step
# Epoch 224/300
# 50/50 - 0s - loss: 0.3683 - accuracy: 0.8625 - val_loss: 0.5597 - val_accuracy: 0.7987 - 49ms/epoch - 977us/step
# Epoch 225/300
# 50/50 - 0s - loss: 0.3621 - accuracy: 0.8633 - val_loss: 0.5325 - val_accuracy: 0.8019 - 41ms/epoch - 810us/step
# Epoch 226/300
# 50/50 - 0s - loss: 0.3627 - accuracy: 0.8645 - val_loss: 0.5632 - val_accuracy: 0.8037 - 40ms/epoch - 791us/step
# Epoch 227/300
# 50/50 - 0s - loss: 0.3782 - accuracy: 0.8586 - val_loss: 0.5524 - val_accuracy: 0.8025 - 40ms/epoch - 800us/step
# Epoch 228/300
# 50/50 - 0s - loss: 0.3796 - accuracy: 0.8511 - val_loss: 0.5622 - val_accuracy: 0.7950 - 47ms/epoch - 946us/step
# Epoch 229/300
# 50/50 - 0s - loss: 0.3688 - accuracy: 0.8597 - val_loss: 0.5601 - val_accuracy: 0.8037 - 45ms/epoch - 891us/step
# Epoch 230/300
# 50/50 - 0s - loss: 0.3740 - accuracy: 0.8558 - val_loss: 0.5783 - val_accuracy: 0.7962 - 44ms/epoch - 880us/step
# Epoch 231/300
# 50/50 - 0s - loss: 0.3765 - accuracy: 0.8548 - val_loss: 0.5636 - val_accuracy: 0.7975 - 43ms/epoch - 868us/step
# Epoch 232/300
# 50/50 - 0s - loss: 0.3754 - accuracy: 0.8619 - val_loss: 0.5676 - val_accuracy: 0.8006 - 41ms/epoch - 823us/step
# Epoch 233/300
# 50/50 - 0s - loss: 0.3647 - accuracy: 0.8672 - val_loss: 0.5713 - val_accuracy: 0.7962 - 40ms/epoch - 804us/step
# Epoch 234/300
# 50/50 - 0s - loss: 0.3543 - accuracy: 0.8680 - val_loss: 0.5641 - val_accuracy: 0.7900 - 38ms/epoch - 769us/step
# Epoch 235/300
# 50/50 - 0s - loss: 0.3800 - accuracy: 0.8611 - val_loss: 0.5568 - val_accuracy: 0.7956 - 40ms/epoch - 792us/step
# Epoch 236/300
# 50/50 - 0s - loss: 0.3923 - accuracy: 0.8569 - val_loss: 0.5471 - val_accuracy: 0.8000 - 39ms/epoch - 778us/step
# Epoch 237/300
# 50/50 - 0s - loss: 0.3700 - accuracy: 0.8581 - val_loss: 0.5640 - val_accuracy: 0.7981 - 41ms/epoch - 825us/step
# Epoch 238/300
# 50/50 - 0s - loss: 0.3743 - accuracy: 0.8630 - val_loss: 0.5611 - val_accuracy: 0.8069 - 39ms/epoch - 784us/step
# Epoch 239/300
# 50/50 - 0s - loss: 0.3772 - accuracy: 0.8491 - val_loss: 0.5696 - val_accuracy: 0.7994 - 39ms/epoch - 781us/step
# Epoch 240/300
# 50/50 - 0s - loss: 0.3791 - accuracy: 0.8603 - val_loss: 0.5536 - val_accuracy: 0.8037 - 39ms/epoch - 789us/step
# Epoch 241/300
# 50/50 - 0s - loss: 0.3669 - accuracy: 0.8659 - val_loss: 0.5645 - val_accuracy: 0.8056 - 41ms/epoch - 822us/step
# Epoch 242/300
# 50/50 - 0s - loss: 0.3578 - accuracy: 0.8647 - val_loss: 0.5791 - val_accuracy: 0.7962 - 41ms/epoch - 810us/step
# Epoch 243/300
# 50/50 - 0s - loss: 0.3834 - accuracy: 0.8580 - val_loss: 0.5772 - val_accuracy: 0.7894 - 40ms/epoch - 794us/step
# Epoch 244/300
# 50/50 - 0s - loss: 0.3701 - accuracy: 0.8595 - val_loss: 0.5864 - val_accuracy: 0.8100 - 40ms/epoch - 793us/step
# Epoch 245/300
# 50/50 - 0s - loss: 0.3660 - accuracy: 0.8583 - val_loss: 0.5684 - val_accuracy: 0.7981 - 40ms/epoch - 799us/step
# Epoch 246/300
# 50/50 - 0s - loss: 0.3690 - accuracy: 0.8587 - val_loss: 0.5484 - val_accuracy: 0.8100 - 40ms/epoch - 807us/step
# Epoch 247/300
# 50/50 - 0s - loss: 0.3724 - accuracy: 0.8620 - val_loss: 0.5549 - val_accuracy: 0.8081 - 40ms/epoch - 799us/step
# Epoch 248/300
# 50/50 - 0s - loss: 0.3688 - accuracy: 0.8652 - val_loss: 0.5613 - val_accuracy: 0.8075 - 39ms/epoch - 789us/step
# Epoch 249/300
# 50/50 - 0s - loss: 0.3778 - accuracy: 0.8545 - val_loss: 0.5605 - val_accuracy: 0.8006 - 39ms/epoch - 776us/step
# Epoch 250/300
# 50/50 - 0s - loss: 0.3634 - accuracy: 0.8595 - val_loss: 0.5686 - val_accuracy: 0.8069 - 40ms/epoch - 796us/step
# Epoch 251/300
# 50/50 - 0s - loss: 0.3699 - accuracy: 0.8587 - val_loss: 0.5664 - val_accuracy: 0.8006 - 39ms/epoch - 788us/step
# Epoch 252/300
# 50/50 - 0s - loss: 0.3606 - accuracy: 0.8608 - val_loss: 0.5633 - val_accuracy: 0.8075 - 39ms/epoch - 787us/step
# Epoch 253/300
# 50/50 - 0s - loss: 0.3532 - accuracy: 0.8686 - val_loss: 0.5775 - val_accuracy: 0.7925 - 40ms/epoch - 804us/step
# Epoch 254/300
# 50/50 - 0s - loss: 0.3673 - accuracy: 0.8602 - val_loss: 0.5489 - val_accuracy: 0.8037 - 40ms/epoch - 799us/step
# Epoch 255/300
# 50/50 - 0s - loss: 0.3667 - accuracy: 0.8573 - val_loss: 0.5524 - val_accuracy: 0.8112 - 39ms/epoch - 787us/step
# Epoch 256/300
# 50/50 - 0s - loss: 0.3717 - accuracy: 0.8577 - val_loss: 0.5634 - val_accuracy: 0.8100 - 39ms/epoch - 788us/step
# Epoch 257/300
# 50/50 - 0s - loss: 0.3604 - accuracy: 0.8611 - val_loss: 0.5737 - val_accuracy: 0.7975 - 40ms/epoch - 797us/step
# Epoch 258/300
# 50/50 - 0s - loss: 0.3672 - accuracy: 0.8572 - val_loss: 0.5555 - val_accuracy: 0.8012 - 40ms/epoch - 800us/step
# Epoch 259/300
# 50/50 - 0s - loss: 0.3568 - accuracy: 0.8634 - val_loss: 0.5404 - val_accuracy: 0.8119 - 40ms/epoch - 794us/step
# Epoch 260/300
# 50/50 - 0s - loss: 0.3576 - accuracy: 0.8617 - val_loss: 0.5688 - val_accuracy: 0.8056 - 40ms/epoch - 797us/step
# Epoch 261/300
# 50/50 - 0s - loss: 0.3620 - accuracy: 0.8611 - val_loss: 0.5643 - val_accuracy: 0.8075 - 40ms/epoch - 791us/step
# Epoch 262/300
# 50/50 - 0s - loss: 0.3637 - accuracy: 0.8606 - val_loss: 0.5676 - val_accuracy: 0.8069 - 40ms/epoch - 800us/step
# Epoch 263/300
# 50/50 - 0s - loss: 0.3557 - accuracy: 0.8687 - val_loss: 0.5645 - val_accuracy: 0.8106 - 40ms/epoch - 794us/step
# Epoch 264/300
# 50/50 - 0s - loss: 0.3690 - accuracy: 0.8608 - val_loss: 0.5550 - val_accuracy: 0.7987 - 40ms/epoch - 801us/step
# Epoch 265/300
# 50/50 - 0s - loss: 0.3515 - accuracy: 0.8709 - val_loss: 0.5510 - val_accuracy: 0.8044 - 41ms/epoch - 813us/step
# Epoch 266/300
# 50/50 - 0s - loss: 0.3644 - accuracy: 0.8595 - val_loss: 0.5578 - val_accuracy: 0.7937 - 40ms/epoch - 803us/step
# Epoch 267/300
# 50/50 - 0s - loss: 0.3802 - accuracy: 0.8577 - val_loss: 0.5542 - val_accuracy: 0.7906 - 40ms/epoch - 800us/step
# Epoch 268/300
# 50/50 - 0s - loss: 0.3685 - accuracy: 0.8628 - val_loss: 0.5676 - val_accuracy: 0.7969 - 38ms/epoch - 762us/step
# Epoch 269/300
# 50/50 - 0s - loss: 0.3629 - accuracy: 0.8597 - val_loss: 0.5807 - val_accuracy: 0.8000 - 40ms/epoch - 799us/step
# Epoch 270/300
# 50/50 - 0s - loss: 0.3754 - accuracy: 0.8658 - val_loss: 0.5741 - val_accuracy: 0.8037 - 40ms/epoch - 805us/step
# Epoch 271/300
# 50/50 - 0s - loss: 0.3678 - accuracy: 0.8641 - val_loss: 0.5732 - val_accuracy: 0.7981 - 39ms/epoch - 783us/step
# Epoch 272/300
# 50/50 - 0s - loss: 0.3567 - accuracy: 0.8644 - val_loss: 0.5702 - val_accuracy: 0.8044 - 40ms/epoch - 803us/step
# Epoch 273/300
# 50/50 - 0s - loss: 0.3556 - accuracy: 0.8637 - val_loss: 0.5582 - val_accuracy: 0.8000 - 40ms/epoch - 801us/step
# Epoch 274/300
# 50/50 - 0s - loss: 0.3575 - accuracy: 0.8623 - val_loss: 0.5654 - val_accuracy: 0.8119 - 40ms/epoch - 806us/step
# Epoch 275/300
# 50/50 - 0s - loss: 0.3657 - accuracy: 0.8627 - val_loss: 0.5512 - val_accuracy: 0.8019 - 40ms/epoch - 807us/step
# Epoch 276/300
# 50/50 - 0s - loss: 0.3746 - accuracy: 0.8612 - val_loss: 0.5599 - val_accuracy: 0.8056 - 40ms/epoch - 801us/step
# Epoch 277/300
# 50/50 - 0s - loss: 0.3614 - accuracy: 0.8587 - val_loss: 0.5936 - val_accuracy: 0.7937 - 40ms/epoch - 798us/step
# Epoch 278/300
# 50/50 - 0s - loss: 0.3605 - accuracy: 0.8645 - val_loss: 0.5702 - val_accuracy: 0.8081 - 41ms/epoch - 824us/step
# Epoch 279/300
# 50/50 - 0s - loss: 0.3450 - accuracy: 0.8673 - val_loss: 0.5796 - val_accuracy: 0.7994 - 40ms/epoch - 800us/step
# Epoch 280/300
# 50/50 - 0s - loss: 0.3527 - accuracy: 0.8622 - val_loss: 0.5691 - val_accuracy: 0.7937 - 40ms/epoch - 805us/step
# Epoch 281/300
# 50/50 - 0s - loss: 0.3502 - accuracy: 0.8705 - val_loss: 0.5745 - val_accuracy: 0.8056 - 40ms/epoch - 798us/step
# Epoch 282/300
# 50/50 - 0s - loss: 0.3457 - accuracy: 0.8691 - val_loss: 0.5730 - val_accuracy: 0.8037 - 40ms/epoch - 796us/step
# Epoch 283/300
# 50/50 - 0s - loss: 0.3590 - accuracy: 0.8723 - val_loss: 0.5840 - val_accuracy: 0.8044 - 39ms/epoch - 785us/step
# Epoch 284/300
# 50/50 - 0s - loss: 0.3609 - accuracy: 0.8692 - val_loss: 0.5865 - val_accuracy: 0.7994 - 40ms/epoch - 798us/step
# Epoch 285/300
# 50/50 - 0s - loss: 0.3571 - accuracy: 0.8642 - val_loss: 0.5810 - val_accuracy: 0.7950 - 40ms/epoch - 799us/step
# Epoch 286/300
# 50/50 - 0s - loss: 0.3647 - accuracy: 0.8619 - val_loss: 0.5689 - val_accuracy: 0.7987 - 42ms/epoch - 832us/step
# Epoch 287/300
# 50/50 - 0s - loss: 0.3398 - accuracy: 0.8687 - val_loss: 0.5851 - val_accuracy: 0.8106 - 42ms/epoch - 836us/step
# Epoch 288/300
# 50/50 - 0s - loss: 0.3616 - accuracy: 0.8661 - val_loss: 0.5868 - val_accuracy: 0.7944 - 41ms/epoch - 810us/step
# Epoch 289/300
# 50/50 - 0s - loss: 0.3503 - accuracy: 0.8653 - val_loss: 0.5737 - val_accuracy: 0.8044 - 41ms/epoch - 817us/step
# Epoch 290/300
# 50/50 - 0s - loss: 0.3705 - accuracy: 0.8587 - val_loss: 0.5623 - val_accuracy: 0.7994 - 41ms/epoch - 812us/step
# Epoch 291/300
# 50/50 - 0s - loss: 0.3688 - accuracy: 0.8634 - val_loss: 0.5624 - val_accuracy: 0.8019 - 41ms/epoch - 813us/step
# Epoch 292/300
# 50/50 - 0s - loss: 0.3546 - accuracy: 0.8664 - val_loss: 0.5625 - val_accuracy: 0.8069 - 40ms/epoch - 801us/step
# Epoch 293/300
# 50/50 - 0s - loss: 0.3614 - accuracy: 0.8606 - val_loss: 0.5689 - val_accuracy: 0.7975 - 41ms/epoch - 822us/step
# Epoch 294/300
# 50/50 - 0s - loss: 0.3574 - accuracy: 0.8672 - val_loss: 0.5689 - val_accuracy: 0.8062 - 44ms/epoch - 872us/step
# Epoch 295/300
# 50/50 - 0s - loss: 0.3529 - accuracy: 0.8627 - val_loss: 0.5699 - val_accuracy: 0.8019 - 43ms/epoch - 859us/step
# Epoch 296/300
# 50/50 - 0s - loss: 0.3584 - accuracy: 0.8648 - val_loss: 0.5633 - val_accuracy: 0.8031 - 44ms/epoch - 888us/step
# Epoch 297/300
# 50/50 - 0s - loss: 0.3518 - accuracy: 0.8673 - val_loss: 0.5700 - val_accuracy: 0.8019 - 42ms/epoch - 834us/step
# Epoch 298/300
# 50/50 - 0s - loss: 0.3609 - accuracy: 0.8653 - val_loss: 0.5614 - val_accuracy: 0.8019 - 41ms/epoch - 817us/step
# Epoch 299/300
# 50/50 - 0s - loss: 0.3714 - accuracy: 0.8628 - val_loss: 0.5889 - val_accuracy: 0.8069 - 40ms/epoch - 802us/step
# Epoch 300/300
# 50/50 - 0s - loss: 0.3518 - accuracy: 0.8697 - val_loss: 0.5696 - val_accuracy: 0.7912 - 41ms/epoch - 812us/step
# before trans:
# (6400, 65)
# (1600, 65)
# after trans:
# (6400, 79)
# (1600, 79)
# Best hyperparameters: {'C': 1, 'gamma': 0.01}
# Best score: 0.7753125
# before trans:
# (6400, 65)
# (1600, 65)
# after trans:
# (6400, 79)
# (1600, 79)
# Best hyperparameters: {'C': 1, 'gamma': 0.01}
# Best score: 0.77515625
# before trans:
# (6400, 65)
# (1600, 65)
# after trans:
# (6400, 79)
# (1600, 79)
# Best hyperparameters: {'C': 1, 'gamma': 0.01}
# Best score: 0.780625
# before trans:
# (6400, 65)
# (1600, 65)
# after trans:
# (6400, 79)
# (1600, 79)
# Best hyperparameters: {'C': 1, 'gamma': 0.01}
# Best score: 0.775625
# before trans:
# (6400, 65)
# (1600, 65)
# after trans:
# (6400, 79)
# (1600, 79)
# Best hyperparameters: {'C': 1, 'gamma': 0.01}
# Best score: 0.77359375
# 63/63 [==============================] - 0s 264us/step
# 63/63 [==============================] - 0s 262us/step
# 63/63 [==============================] - 0s 270us/step
# 63/63 [==============================] - 0s 252us/step
# 63/63 [==============================] - 0s 246us/step

# %%
# Make predictions for XGBoost
make_predictions(test_xgb, xgb_model_list, xgb_transformer_list)

# Combine the predictions from all models
class_predictions_array = np.array(class_predictions_list)
final_predictions = mode(class_predictions_array, axis=0).mode[0]

# Add predicted return percentage and grade to the test dataset
test_xgb['predicted_return_percentage'] = test_xgb['model_predictions']
test_xgb['predicted_grade'] = final_predictions

# Print the updated dataset
print(test_xgb[['predicted_return_percentage', 'predicted_grade']])
# Out:
#          predicted_return_percentage  predicted_grade
# 1900401                     0.903391                1
# 1900402                     0.900195                1
# 1900403                     0.921092                1
# 1900404                     0.813835                1
# 1900405                     0.920004                1
# ...                              ...              ...
# 1902619                     0.933729                1
# 1902621                     0.986809                1
# 1902622                     0.908161                1
# 1902623                     0.929424                1
# 1902624                     0.998673                1
#
# [2000 rows x 2 columns]

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import ColumnTransformer



# Calculate the Fraction of Return and predicted Loan Grade for each loan
fraction_of_return = test_xgb["predicted_return_percentage"]
grade = test_xgb['predicted_grade']

# Define the initial thresholds
initial_min_fraction_of_return = 0
initial_max_loan_grade = 6  # Assuming Grade B is the minimum acceptable loan grade

# Initialize variables to track the best threshold values and maximum profit
best_min_fraction_of_return = initial_min_fraction_of_return
best_min_loan_grade = initial_max_loan_grade
max_profit = 0

# Iterate through different threshold values to find the maximum profit
for min_fraction_of_return in np.arange(initial_min_fraction_of_return, 1.0, 0.001):
    for max_loan_grade in [0, 1, 2, 3, 4, 5, 6]:
        # Filter the loans that meet the threshold criteria
        approved_loans = test_xgb[
            (fraction_of_return >= min_fraction_of_return) & (grade <= max_loan_grade)
            ]

        # Calculate the profit for each approved loan
        approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]

        # Calculate the total company profit
        total_profit = approved_loans["profit"].sum()

        # Update the maximum profit and best threshold values if a higher profit is achieved
        if total_profit > max_profit:
            max_profit = total_profit
            best_min_fraction_of_return = min_fraction_of_return
            best_min_loan_grade = max_loan_grade

# Print the best threshold values and maximum profit
print("Best Threshold Values:")
print(f"Minimum acceptable Fraction of Return: {best_min_fraction_of_return:.2f}")
print(f"Minimum acceptable Loan Grade: {best_min_loan_grade}")
print(f"Maximum Profit: {max_profit:.2f}")
# Out:
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
# /var/folders/36/3tgz8yyx0c9b0j6sl4g1myf40000gn/T/ipykernel_12236/1904043691.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   approved_loans["profit"] = approved_loans["expected_return"]*fraction_of_return - approved_loans["loan_amnt"]
